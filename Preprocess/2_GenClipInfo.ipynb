# %% [markdown]
# **Before this process**, you should delete all temporary folders (abandoned, troublesome, low_quality) manually to proceed.
#
# ---
#
# This notebook will generate cilp info for further clipping.

# %%
import sys
if '../' not in sys.path:
    sys.path.append('../')
from Utils.FileOperation import *
from Config import rootDir

import cv2
import statistics
import json
import statistics
from copy import deepcopy

# %%
def gen_clip_len_list(
        len_per_vid,
        vid_category_dict,
        max_splits=None
    ):
    '''
    Parameters
        len_per_vid: frame count for each video clip
        vid_category_dict: dict of lists of video categories, contains 4 lists of cropped video paths,
            should be like {'fake_train': [...], 'fake_test': [...], 'real_train': [...], 'real_test': [...]}
        max_splits: maximum number of splits,
            e.g. if max_splits = 5, len_per_vid=10, actual video length is 65,
                it will be split into 5 clips of length 10 instead of 6 clips
            None means no limit
    '''
    vid_category_dict = deepcopy(vid_category_dict)
    # Get split number for each video
    for vid_category_key in vid_category_dict.keys():
        for i, vid_path in enumerate(vid_category_dict[vid_category_key]):
            vid = cv2.VideoCapture(vid_path)
            vid_len = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
            split_num = int(vid_len // len_per_vid)
            if max_splits and 'train' in vid_category_key:
                split_num = min(split_num, max_splits)
            vid.release()
            vid_category_dict[vid_category_key][i] = {'path': vid_path, 'split_num': split_num, 'vid_len': vid_len}
    # Get split number for each category
    split_num_dict = {}
    for vid_category_key in vid_category_dict.keys():
        split_num_dict[vid_category_key] = sum(
            [vid['split_num'] for vid in vid_category_dict[vid_category_key]]
        )
    print('split_num_dict before tweaking:', split_num_dict)
    # Make fake_train and real_train have the same number of splits by reducing the category with more splits
    # Cut one split from the video with the most splits until two categories have the same number of splits
    more_split_category = 'fake_train' if split_num_dict['fake_train'] > split_num_dict['real_train'] else 'real_train'
    while split_num_dict['fake_train'] != split_num_dict['real_train']:
        # Find the video with the most splits
        max_split_vid = max(vid_category_dict[more_split_category], key=lambda x: x['split_num'])
        # print('max_split_vid:', max_split_vid)
        # Cut one split from the video with the most splits
        max_split_vid['split_num'] -= 1
        # Update split number list
        split_num_dict[more_split_category] -= 1
    print('split_num_dict after tweaking:', split_num_dict)
    vid_category_dict['len_per_vid'] = len_per_vid
    return vid_category_dict

# %%
def display_statistic_info(myData, tab_num=0):
    print('\t' * tab_num + 'min:', min(myData))
    print('\t' * tab_num + 'max:', max(myData))
    print('\t' * tab_num + 'mean:', round(sum(myData) / len(myData), 2))
    print('\t' * tab_num + 'median:', int(statistics.median(myData)))



def display_category_dict_info(vid_category_dict):
    print('Fake Train:\n\tvid_len:')
    display_statistic_info([vid['vid_len'] for vid in vid_category_dict['fake_train']], tab_num=2)
    print('\tsplit_num:')
    display_statistic_info([vid['split_num'] for vid in vid_category_dict['fake_train']], tab_num=2)
    print('Fake Test:\n\tvid_len:')
    display_statistic_info([vid['vid_len'] for vid in vid_category_dict['fake_test']], tab_num=2)
    print('\tsplit_num:')
    display_statistic_info([vid['split_num'] for vid in vid_category_dict['fake_test']], tab_num=2)
    print('Real Train:\n\tvid_len:')
    display_statistic_info([vid['vid_len'] for vid in vid_category_dict['real_train']], tab_num=2)
    print('\tsplit_num:')
    display_statistic_info([vid['split_num'] for vid in vid_category_dict['real_train']], tab_num=2)
    print('Real Test:\n\tvid_len:')
    display_statistic_info([vid['vid_len'] for vid in vid_category_dict['real_test']], tab_num=2)
    print('\tsplit_num:')
    display_statistic_info([vid['split_num'] for vid in vid_category_dict['real_test']], tab_num=2)

# %% [markdown]
# **CDF**

# %%
CDF_vid_category_dict = {'fake_train': None, 'fake_test': None, 'real_train': None, 'real_test': None}
with open(rootDir + 'cropped_videos/CDF_crop/List_of_testing_videos.txt', 'r') as f:
    CDF_test_list = f.readlines()
    CDF_vid_category_dict['fake_test'] = [rootDir + 'cropped_videos/CDF_crop/' + vid[2:].replace('\n', '') for vid in CDF_test_list if vid[0] == '0']
    CDF_vid_category_dict['real_test'] = [rootDir + 'cropped_videos/CDF_crop/' + vid[2:].replace('\n', '') for vid in CDF_test_list if vid[0] == '1']
all_CDF_videos = [rootDir + 'cropped_videos/CDF_crop/' + vid for vid in fileWalk(rootDir + 'cropped_videos/CDF_crop/') if vid[-4:] == '.mp4']
CDF_vid_category_dict['fake_train'] = [vid for vid in all_CDF_videos if vid not in CDF_vid_category_dict['fake_test']]
CDF_vid_category_dict['fake_train'] = [vid for vid in CDF_vid_category_dict['fake_train'] if 'synthesis' in vid]
CDF_vid_category_dict['real_train'] = [vid for vid in all_CDF_videos if vid not in CDF_vid_category_dict['real_test']]
CDF_vid_category_dict['real_train'] = [vid for vid in CDF_vid_category_dict['real_train'] if 'real' in vid]

# %%
CDF_vid_category_dict = gen_clip_len_list(
    len_per_vid=14,
    vid_category_dict=CDF_vid_category_dict,
    max_splits=None
)
# Out:
# split_num_dict before tweaking: {'fake_train': 139528, 'fake_test': 8977, 'real_train': 20268, 'real_test': 4940}
# split_num_dict after tweaking: {'fake_train': 20268, 'fake_test': 8977, 'real_train': 20268, 'real_test': 4940}

# %%
display_category_dict_info(CDF_vid_category_dict)
# Out:
# Fake Train:
# 	vid_len:
# 		min: 161
# 		max: 740
# 		mean: 375.28
# 		median: 342
# 	split_num:
# 		min: 3
# 		max: 4
# 		mean: 3.82
# 		median: 4
# Fake Test:
# 	vid_len:
# 		min: 105
# 		max: 639
# 		mean: 376.21
# 		median: 365
# 	split_num:
# 		min: 7
# 		max: 45
# 		mean: 26.4
# 		median: 26
# Real Train:
# 	vid_len:
# 		min: 161
# 		max: 740
# 		mean: 405.51
# 		median: 428
# 	split_num:
# 		min: 11
# 		max: 52
# 		mean: 28.51
# 		median: 30
# Real Test:
# 	vid_len:
# 		min: 126
# 		max: 611
# 		mean: 394.99
# 		median: 410
# 	split_num:
# 		min: 9
# 		max: 43
# 		mean: 27.75
# 		median: 29

# %%
CDF_vid_category_dict
# Out:
# {'fake_train': [{'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id45_0004.mp4',
#    'split_num': 3,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id4_0004.mp4',
#    'split_num': 3,
#    'vid_len': 499},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id13_id7_0008.mp4',
#    'split_num': 3,
#    'vid_len': 459},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id9_0004.mp4',
#    'split_num': 3,
#    'vid_len': 409},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id39_id47_0001.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id30_0005.mp4',
#    'split_num': 3,
#    'vid_len': 467},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id29_0001.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id44_0004.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id37_0007.mp4',
#    'split_num': 3,
#    'vid_len': 503},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id9_0009.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id26_0002.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id54_0005.mp4',
#    'split_num': 3,
#    'vid_len': 464},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id22_0006.mp4',
#    'split_num': 3,
#    'vid_len': 328},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id44_id47_0005.mp4',
#    'split_num': 3,
#    'vid_len': 333},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id38_id26_0007.mp4',
#    'split_num': 3,
#    'vid_len': 456},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id4_0001.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id49_0006.mp4',
#    'split_num': 3,
#    'vid_len': 455},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id2_0001.mp4',
#    'split_num': 3,
#    'vid_len': 369},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id56_id49_0005.mp4',
#    'split_num': 3,
#    'vid_len': 469},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id9_0000.mp4',
#    'split_num': 3,
#    'vid_len': 318},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id43_id42_0005.mp4',
#    'split_num': 3,
#    'vid_len': 333},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id2_0000.mp4',
#    'split_num': 3,
#    'vid_len': 317},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id49_0008.mp4',
#    'split_num': 3,
#    'vid_len': 551},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id22_id24_0002.mp4',
#    'split_num': 3,
#    'vid_len': 283},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id2_0007.mp4',
#    'split_num': 3,
#    'vid_len': 347},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id26_0002.mp4',
#    'split_num': 3,
#    'vid_len': 452},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id4_0006.mp4',
#    'split_num': 3,
#    'vid_len': 328},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id20_0009.mp4',
#    'split_num': 3,
#    'vid_len': 475},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id0_id17_0007.mp4',
#    'split_num': 3,
#    'vid_len': 479},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id9_0003.mp4',
#    'split_num': 3,
#    'vid_len': 186},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id22_id19_0002.mp4',
#    'split_num': 3,
#    'vid_len': 283},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id53_id51_0009.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id39_0002.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id3_0003.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id54_id56_0007.mp4',
#    'split_num': 3,
#    'vid_len': 571},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id17_0003.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id37_0010.mp4',
#    'split_num': 3,
#    'vid_len': 325},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id35_0004.mp4',
#    'split_num': 3,
#    'vid_len': 225},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id2_0005.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id19_0002.mp4',
#    'split_num': 3,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id17_0004.mp4',
#    'split_num': 3,
#    'vid_len': 425},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id0_0008.mp4',
#    'split_num': 3,
#    'vid_len': 325},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id3_0008.mp4',
#    'split_num': 3,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id23_0002.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id46_0005.mp4',
#    'split_num': 3,
#    'vid_len': 322},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id55_id58_0002.mp4',
#    'split_num': 3,
#    'vid_len': 418},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id38_0004.mp4',
#    'split_num': 3,
#    'vid_len': 404},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id37_0001.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id57_0008.mp4',
#    'split_num': 3,
#    'vid_len': 551},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id34_0001.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id20_0005.mp4',
#    'split_num': 3,
#    'vid_len': 307},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id17_id31_0002.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id44_0005.mp4',
#    'split_num': 3,
#    'vid_len': 230},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id26_id0_0006.mp4',
#    'split_num': 3,
#    'vid_len': 307},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id0_0006.mp4',
#    'split_num': 3,
#    'vid_len': 409},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id29_0000.mp4',
#    'split_num': 3,
#    'vid_len': 502},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id32_0001.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id16_0009.mp4',
#    'split_num': 3,
#    'vid_len': 321},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id30_0001.mp4',
#    'split_num': 3,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id38_0001.mp4',
#    'split_num': 3,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id4_0004.mp4',
#    'split_num': 3,
#    'vid_len': 465},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id35_0006.mp4',
#    'split_num': 3,
#    'vid_len': 224},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id44_0001.mp4',
#    'split_num': 3,
#    'vid_len': 250},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id55_0007.mp4',
#    'split_num': 3,
#    'vid_len': 494},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id1_0008.mp4',
#    'split_num': 3,
#    'vid_len': 461},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id24_0005.mp4',
#    'split_num': 3,
#    'vid_len': 308},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id39_id42_0004.mp4',
#    'split_num': 3,
#    'vid_len': 280},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id42_id43_0001.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id6_0003.mp4',
#    'split_num': 3,
#    'vid_len': 442},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id24_id23_0007.mp4',
#    'split_num': 3,
#    'vid_len': 308},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id41_0006.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id0_0009.mp4',
#    'split_num': 3,
#    'vid_len': 483},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id55_id53_0004.mp4',
#    'split_num': 3,
#    'vid_len': 449},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id28_0005.mp4',
#    'split_num': 3,
#    'vid_len': 448},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id44_id46_0002.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id0_id26_0004.mp4',
#    'split_num': 3,
#    'vid_len': 326},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id30_0007.mp4',
#    'split_num': 3,
#    'vid_len': 473},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id25_id20_0010.mp4',
#    'split_num': 3,
#    'vid_len': 355},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id35_0001.mp4',
#    'split_num': 3,
#    'vid_len': 446},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id58_id57_0006.mp4',
#    'split_num': 3,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id38_0009.mp4',
#    'split_num': 3,
#    'vid_len': 321},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id25_id27_0003.mp4',
#    'split_num': 3,
#    'vid_len': 250},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id54_id53_0008.mp4',
#    'split_num': 3,
#    'vid_len': 349},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id38_0004.mp4',
#    'split_num': 3,
#    'vid_len': 417},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id4_0009.mp4',
#    'split_num': 3,
#    'vid_len': 530},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id42_0004.mp4',
#    'split_num': 3,
#    'vid_len': 329},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id22_id26_0009.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id6_0002.mp4',
#    'split_num': 3,
#    'vid_len': 400},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id20_0003.mp4',
#    'split_num': 3,
#    'vid_len': 186},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id6_0006.mp4',
#    'split_num': 3,
#    'vid_len': 401},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id44_0009.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id51_id49_0000.mp4',
#    'split_num': 3,
#    'vid_len': 438},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id42_0008.mp4',
#    'split_num': 3,
#    'vid_len': 321},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id50_id51_0004.mp4',
#    'split_num': 3,
#    'vid_len': 473},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id51_id58_0004.mp4',
#    'split_num': 3,
#    'vid_len': 447},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id31_0002.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id20_0001.mp4',
#    'split_num': 3,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id38_0000.mp4',
#    'split_num': 3,
#    'vid_len': 504},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id57_id55_0006.mp4',
#    'split_num': 3,
#    'vid_len': 453},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id4_0006.mp4',
#    'split_num': 3,
#    'vid_len': 401},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id44_id48_0003.mp4',
#    'split_num': 3,
#    'vid_len': 342},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id57_id55_0001.mp4',
#    'split_num': 3,
#    'vid_len': 457},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id60_id59_0009.mp4',
#    'split_num': 3,
#    'vid_len': 466},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id26_0006.mp4',
#    'split_num': 3,
#    'vid_len': 409},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id23_0006.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id2_0003.mp4',
#    'split_num': 3,
#    'vid_len': 470},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id0_0001.mp4',
#    'split_num': 3,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id34_0007.mp4',
#    'split_num': 3,
#    'vid_len': 456},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id49_0004.mp4',
#    'split_num': 3,
#    'vid_len': 513},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id43_id42_0009.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id49_id52_0001.mp4',
#    'split_num': 3,
#    'vid_len': 460},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id31_0006.mp4',
#    'split_num': 3,
#    'vid_len': 401},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id26_id29_0001.mp4',
#    'split_num': 3,
#    'vid_len': 320},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id22_id20_0001.mp4',
#    'split_num': 3,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id42_0001.mp4',
#    'split_num': 3,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id47_0008.mp4',
#    'split_num': 3,
#    'vid_len': 321},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id29_id20_0008.mp4',
#    'split_num': 3,
#    'vid_len': 450},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id45_0000.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id30_0001.mp4',
#    'split_num': 3,
#    'vid_len': 508},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id38_id31_0009.mp4',
#    'split_num': 3,
#    'vid_len': 585},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id37_0004.mp4',
#    'split_num': 3,
#    'vid_len': 465},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id57_id50_0000.mp4',
#    'split_num': 3,
#    'vid_len': 639},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id6_0007.mp4',
#    'split_num': 3,
#    'vid_len': 470},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id47_0009.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id39_0004.mp4',
#    'split_num': 3,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id54_0008.mp4',
#    'split_num': 3,
#    'vid_len': 551},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id1_0004.mp4',
#    'split_num': 3,
#    'vid_len': 410},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id48_0007.mp4',
#    'split_num': 3,
#    'vid_len': 333},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id3_0007.mp4',
#    'split_num': 3,
#    'vid_len': 284},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id40_0003.mp4',
#    'split_num': 3,
#    'vid_len': 335},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id49_id50_0001.mp4',
#    'split_num': 3,
#    'vid_len': 460},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id2_0002.mp4',
#    'split_num': 3,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id32_id35_0004.mp4',
#    'split_num': 3,
#    'vid_len': 428},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id19_id27_0008.mp4',
#    'split_num': 3,
#    'vid_len': 324},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id53_id58_0003.mp4',
#    'split_num': 3,
#    'vid_len': 472},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id28_0005.mp4',
#    'split_num': 3,
#    'vid_len': 349},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id37_0001.mp4',
#    'split_num': 3,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id20_0001.mp4',
#    'split_num': 3,
#    'vid_len': 290},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id31_0007.mp4',
#    'split_num': 3,
#    'vid_len': 446},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id8_id7_0008.mp4',
#    'split_num': 3,
#    'vid_len': 570},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id44_0008.mp4',
#    'split_num': 3,
#    'vid_len': 331},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id6_0002.mp4',
#    'split_num': 3,
#    'vid_len': 363},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id53_id58_0004.mp4',
#    'split_num': 3,
#    'vid_len': 477},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id9_0006.mp4',
#    'split_num': 3,
#    'vid_len': 323},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id33_0006.mp4',
#    'split_num': 3,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id20_0009.mp4',
#    'split_num': 3,
#    'vid_len': 412},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id37_0009.mp4',
#    'split_num': 3,
#    'vid_len': 455},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id29_id34_0009.mp4',
#    'split_num': 3,
#    'vid_len': 474},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id33_0008.mp4',
#    'split_num': 3,
#    'vid_len': 483},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id28_0001.mp4',
#    'split_num': 3,
#    'vid_len': 322},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id34_id32_0001.mp4',
#    'split_num': 3,
#    'vid_len': 419},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id38_0001.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id25_id20_0008.mp4',
#    'split_num': 3,
#    'vid_len': 323},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id38_id23_0007.mp4',
#    'split_num': 3,
#    'vid_len': 456},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id29_0004.mp4',
#    'split_num': 3,
#    'vid_len': 465},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id51_id56_0002.mp4',
#    'split_num': 3,
#    'vid_len': 302},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id25_0000.mp4',
#    'split_num': 3,
#    'vid_len': 318},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id28_0002.mp4',
#    'split_num': 3,
#    'vid_len': 311},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id29_id26_0005.mp4',
#    'split_num': 3,
#    'vid_len': 468},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id31_0007.mp4',
#    'split_num': 3,
#    'vid_len': 301},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id3_0005.mp4',
#    'split_num': 3,
#    'vid_len': 422},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id42_id39_0000.mp4',
#    'split_num': 3,
#    'vid_len': 347},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id58_id57_0001.mp4',
#    'split_num': 3,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id43_id48_0002.mp4',
#    'split_num': 3,
#    'vid_len': 335},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id37_0005.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id19_id22_0006.mp4',
#    'split_num': 3,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id44_id43_0003.mp4',
#    'split_num': 3,
#    'vid_len': 342},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id42_id47_0001.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id26_id2_0001.mp4',
#    'split_num': 3,
#    'vid_len': 320},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id35_0005.mp4',
#    'split_num': 3,
#    'vid_len': 308},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id45_0003.mp4',
#    'split_num': 3,
#    'vid_len': 335},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id2_0005.mp4',
#    'split_num': 3,
#    'vid_len': 448},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id21_0009.mp4',
#    'split_num': 3,
#    'vid_len': 475},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id60_id61_0009.mp4',
#    'split_num': 3,
#    'vid_len': 466},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id0_0004.mp4',
#    'split_num': 3,
#    'vid_len': 307},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id43_0007.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id21_0006.mp4',
#    'split_num': 3,
#    'vid_len': 454},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id54_id57_0008.mp4',
#    'split_num': 3,
#    'vid_len': 349},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id37_0009.mp4',
#    'split_num': 3,
#    'vid_len': 475},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id25_id20_0005.mp4',
#    'split_num': 3,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id46_0004.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id26_0002.mp4',
#    'split_num': 3,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id30_0006.mp4',
#    'split_num': 3,
#    'vid_len': 454},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id22_0000.mp4',
#    'split_num': 3,
#    'vid_len': 330},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id16_0007.mp4',
#    'split_num': 3,
#    'vid_len': 455},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id29_0002.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id2_0003.mp4',
#    'split_num': 3,
#    'vid_len': 372},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id31_0002.mp4',
#    'split_num': 3,
#    'vid_len': 311},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id17_0007.mp4',
#    'split_num': 3,
#    'vid_len': 361},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id7_id11_0002.mp4',
#    'split_num': 3,
#    'vid_len': 270},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id32_id21_0002.mp4',
#    'split_num': 3,
#    'vid_len': 494},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id48_0003.mp4',
#    'split_num': 3,
#    'vid_len': 295},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id0_id1_0007.mp4',
#    'split_num': 3,
#    'vid_len': 479},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id46_0002.mp4',
#    'split_num': 3,
#    'vid_len': 286},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id39_0009.mp4',
#    'split_num': 3,
#    'vid_len': 342},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id1_0005.mp4',
#    'split_num': 3,
#    'vid_len': 165},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id17_id1_0005.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id9_0004.mp4',
#    'split_num': 3,
#    'vid_len': 307},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id22_id20_0004.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id55_id58_0006.mp4',
#    'split_num': 3,
#    'vid_len': 259},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id32_0000.mp4',
#    'split_num': 3,
#    'vid_len': 234},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id28_0001.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id13_id10_0000.mp4',
#    'split_num': 3,
#    'vid_len': 327},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id35_0009.mp4',
#    'split_num': 3,
#    'vid_len': 331},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id47_0009.mp4',
#    'split_num': 3,
#    'vid_len': 328},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id9_0005.mp4',
#    'split_num': 3,
#    'vid_len': 422},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id21_0002.mp4',
#    'split_num': 3,
#    'vid_len': 361},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id28_0006.mp4',
#    'split_num': 3,
#    'vid_len': 454},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id6_0005.mp4',
#    'split_num': 3,
#    'vid_len': 398},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id48_0006.mp4',
#    'split_num': 3,
#    'vid_len': 317},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id20_0006.mp4',
#    'split_num': 3,
#    'vid_len': 366},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id25_id20_0002.mp4',
#    'split_num': 3,
#    'vid_len': 341},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id46_id47_0008.mp4',
#    'split_num': 3,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id28_0008.mp4',
#    'split_num': 3,
#    'vid_len': 381},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id1_0002.mp4',
#    'split_num': 3,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id31_0001.mp4',
#    'split_num': 3,
#    'vid_len': 446},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id37_0004.mp4',
#    'split_num': 3,
#    'vid_len': 410},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id26_0005.mp4',
#    'split_num': 3,
#    'vid_len': 345},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id27_id19_0004.mp4',
#    'split_num': 3,
#    'vid_len': 307},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id26_0009.mp4',
#    'split_num': 3,
#    'vid_len': 316},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id4_0002.mp4',
#    'split_num': 3,
#    'vid_len': 364},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id27_id20_0006.mp4',
#    'split_num': 3,
#    'vid_len': 295},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id0_id4_0005.mp4',
#    'split_num': 3,
#    'vid_len': 459},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id34_0005.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id32_id28_0007.mp4',
#    'split_num': 3,
#    'vid_len': 457},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id0_0009.mp4',
#    'split_num': 3,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id31_0004.mp4',
#    'split_num': 3,
#    'vid_len': 417},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id34_0003.mp4',
#    'split_num': 3,
#    'vid_len': 490},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id34_0000.mp4',
#    'split_num': 3,
#    'vid_len': 318},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id6_0004.mp4',
#    'split_num': 3,
#    'vid_len': 499},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id52_id57_0007.mp4',
#    'split_num': 3,
#    'vid_len': 494},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id38_0000.mp4',
#    'split_num': 3,
#    'vid_len': 234},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id37_0011.mp4',
#    'split_num': 3,
#    'vid_len': 272},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id32_0001.mp4',
#    'split_num': 3,
#    'vid_len': 508},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id35_0007.mp4',
#    'split_num': 3,
#    'vid_len': 470},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id0_0003.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id35_0005.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id17_0004.mp4',
#    'split_num': 3,
#    'vid_len': 225},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id28_0012.mp4',
#    'split_num': 3,
#    'vid_len': 308},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id33_0001.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id29_0007.mp4',
#    'split_num': 3,
#    'vid_len': 301},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id0_id3_0008.mp4',
#    'split_num': 3,
#    'vid_len': 464},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id20_0001.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id16_0004.mp4',
#    'split_num': 3,
#    'vid_len': 465},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id27_id19_0003.mp4',
#    'split_num': 3,
#    'vid_len': 283},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id39_0007.mp4',
#    'split_num': 3,
#    'vid_len': 342},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id57_id50_0004.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id42_0009.mp4',
#    'split_num': 3,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id17_id28_0002.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id1_0007.mp4',
#    'split_num': 3,
#    'vid_len': 446},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id19_id21_0009.mp4',
#    'split_num': 3,
#    'vid_len': 341},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id23_0007.mp4',
#    'split_num': 3,
#    'vid_len': 317},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id22_id27_0006.mp4',
#    'split_num': 3,
#    'vid_len': 333},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id34_0003.mp4',
#    'split_num': 3,
#    'vid_len': 353},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id37_0002.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id32_0004.mp4',
#    'split_num': 3,
#    'vid_len': 256},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id29_0009.mp4',
#    'split_num': 3,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id43_id48_0004.mp4',
#    'split_num': 3,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id23_0005.mp4',
#    'split_num': 3,
#    'vid_len': 372},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id34_0000.mp4',
#    'split_num': 3,
#    'vid_len': 441},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id43_0004.mp4',
#    'split_num': 3,
#    'vid_len': 326},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id39_0000.mp4',
#    'split_num': 3,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id29_id35_0002.mp4',
#    'split_num': 3,
#    'vid_len': 434},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id43_0003.mp4',
#    'split_num': 3,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id46_0008.mp4',
#    'split_num': 3,
#    'vid_len': 321},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id56_id51_0007.mp4',
#    'split_num': 3,
#    'vid_len': 235},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id49_id53_0006.mp4',
#    'split_num': 3,
#    'vid_len': 330},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id56_id50_0003.mp4',
#    'split_num': 3,
#    'vid_len': 447},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id3_0006.mp4',
#    'split_num': 3,
#    'vid_len': 294},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id1_0003.mp4',
#    'split_num': 3,
#    'vid_len': 372},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id39_id47_0008.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id47_0005.mp4',
#    'split_num': 3,
#    'vid_len': 230},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id4_0007.mp4',
#    'split_num': 3,
#    'vid_len': 399},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id4_0005.mp4',
#    'split_num': 3,
#    'vid_len': 372},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id6_0000.mp4',
#    'split_num': 3,
#    'vid_len': 423},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id27_0003.mp4',
#    'split_num': 3,
#    'vid_len': 186},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id17_id26_0005.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id4_0002.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id35_0009.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id46_id48_0003.mp4',
#    'split_num': 3,
#    'vid_len': 291},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id25_id26_0005.mp4',
#    'split_num': 3,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id26_id25_0001.mp4',
#    'split_num': 3,
#    'vid_len': 320},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id17_0001.mp4',
#    'split_num': 3,
#    'vid_len': 333},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id38_id35_0003.mp4',
#    'split_num': 3,
#    'vid_len': 475},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id19_id27_0004.mp4',
#    'split_num': 3,
#    'vid_len': 323},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id48_0001.mp4',
#    'split_num': 3,
#    'vid_len': 250},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id42_0009.mp4',
#    'split_num': 3,
#    'vid_len': 316},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id38_id28_0002.mp4',
#    'split_num': 3,
#    'vid_len': 301},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id39_0003.mp4',
#    'split_num': 3,
#    'vid_len': 313},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id27_id25_0003.mp4',
#    'split_num': 3,
#    'vid_len': 283},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id35_0001.mp4',
#    'split_num': 3,
#    'vid_len': 437},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id16_0006.mp4',
#    'split_num': 3,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id44_0000.mp4',
#    'split_num': 3,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id28_0000.mp4',
#    'split_num': 3,
#    'vid_len': 317},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id4_id1_0009.mp4',
#    'split_num': 3,
#    'vid_len': 483},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id28_0006.mp4',
#    'split_num': 3,
#    'vid_len': 401},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id6_0004.mp4',
#    'split_num': 3,
#    'vid_len': 409},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id23_0008.mp4',
#    'split_num': 3,
#    'vid_len': 322},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id20_id38_0009.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id45_0004.mp4',
#    'split_num': 3,
#    'vid_len': 326},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id16_id35_0003.mp4',
#    'split_num': 3,
#    'vid_len': 303},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id46_id42_0004.mp4',
#    'split_num': 3,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id43_0005.mp4',
#    'split_num': 3,
#    'vid_len': 230},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id50_id51_0006.mp4',
#    'split_num': 3,
#    'vid_len': 449},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id26_id27_0001.mp4',
#    'split_num': 3,
#    'vid_len': 320},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id48_id39_0007.mp4',
#    'split_num': 3,
#    'vid_len': 306},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id47_id45_0000.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id43_id45_0004.mp4',
#    'split_num': 3,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id33_id34_0005.mp4',
#    'split_num': 3,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id54_id58_0004.mp4',
#    'split_num': 3,
#    'vid_len': 494},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id0_id16_0009.mp4',
#    'split_num': 3,
#    'vid_len': 520},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id4_0000.mp4',
#    'split_num': 3,
#    'vid_len': 318},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id17_0008.mp4',
#    'split_num': 3,
#    'vid_len': 516},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id17_id1_0001.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id45_0006.mp4',
#    'split_num': 3,
#    'vid_len': 321},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id27_id26_0008.mp4',
#    'split_num': 3,
#    'vid_len': 331},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id4_0001.mp4',
#    'split_num': 3,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id9_id28_0009.mp4',
#    'split_num': 3,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id40_id48_0002.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id39_id46_0007.mp4',
#    'split_num': 3,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id3_id37_0000.mp4',
#    'split_num': 3,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id6_id23_0008.mp4',
#    'split_num': 3,
#    'vid_len': 381},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id25_0002.mp4',
#    'split_num': 3,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id37_id31_0006.mp4',
#    'split_num': 3,
#    'vid_len': 454},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id45_id47_0004.mp4',
#    'split_num': 3,
#    'vid_len': 312},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id24_id23_0000.mp4',
#    'split_num': 3,
#    'vid_len': 292},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id2_id3_0003.mp4',
#    'split_num': 3,
#    'vid_len': 383},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id38_id23_0006.mp4',
#    'split_num': 3,
#    'vid_len': 467},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id31_id30_0002.mp4',
#    'split_num': 3,
#    'vid_len': 485},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id21_id30_0007.mp4',
#    'split_num': 3,
#    'vid_len': 317},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id1_id21_0003.mp4',
#    'split_num': 3,
#    'vid_len': 451},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id56_id57_0003.mp4',
#    'split_num': 3,
#    'vid_len': 447},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id41_id47_0007.mp4',
#    'split_num': 3,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id58_id54_0001.mp4',
#    'split_num': 3,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id22_0006.mp4',
#    'split_num': 3,
#    'vid_len': 323},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id35_id17_0002.mp4',
#    'split_num': 3,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id17_id20_0001.mp4',
#    'split_num': 3,
#    'vid_len': 315},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id24_id26_0000.mp4',
#    'split_num': 3,
#    'vid_len': 292},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id34_id23_0008.mp4',
#    'split_num': 3,
#    'vid_len': 516},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id30_id38_0003.mp4',
#    'split_num': 3,
#    'vid_len': 470},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id23_id22_0002.mp4',
#    'split_num': 3,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id5_id59_0008.mp4',
#    'split_num': 3,
#    'vid_len': 584},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-synthesis/id28_id9_0004.mp4',
#    'split_num': 3,
#    'vid_len': 311},
# ...
#    'split_num': 33,
#    'vid_len': 462},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00276.mp4',
#    'split_num': 32,
#    'vid_len': 461},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00277.mp4',
#    'split_num': 33,
#    'vid_len': 465},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00278.mp4',
#    'split_num': 27,
#    'vid_len': 389},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00279.mp4',
#    'split_num': 32,
#    'vid_len': 453},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00280.mp4',
#    'split_num': 27,
#    'vid_len': 388},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00281.mp4',
#    'split_num': 32,
#    'vid_len': 459},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00282.mp4',
#    'split_num': 31,
#    'vid_len': 442},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00283.mp4',
#    'split_num': 28,
#    'vid_len': 394},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00284.mp4',
#    'split_num': 33,
#    'vid_len': 463},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00285.mp4',
#    'split_num': 32,
#    'vid_len': 448},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00286.mp4',
#    'split_num': 33,
#    'vid_len': 462},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00287.mp4',
#    'split_num': 33,
#    'vid_len': 468},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00288.mp4',
#    'split_num': 33,
#    'vid_len': 469},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/YouTube-real/00289.mp4',
#    'split_num': 22,
#    'vid_len': 313},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id1_0007.mp4',
#    'split_num': 23,
#    'vid_len': 328},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id2_0008.mp4',
#    'split_num': 36,
#    'vid_len': 516},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id3_0001.mp4',
#    'split_num': 27,
#    'vid_len': 380},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id6_0005.mp4',
#    'split_num': 26,
#    'vid_len': 372},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id9_0000.mp4',
#    'split_num': 32,
#    'vid_len': 448},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id11_0008.mp4',
#    'split_num': 26,
#    'vid_len': 371},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id16_0011.mp4',
#    'split_num': 19,
#    'vid_len': 272},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id17_0000.mp4',
#    'split_num': 21,
#    'vid_len': 305},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id35_0008.mp4',
#    'split_num': 14,
#    'vid_len': 209},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id39_0005.mp4',
#    'split_num': 19,
#    'vid_len': 267},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id48_0000.mp4',
#    'split_num': 24,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id32_0008.mp4',
#    'split_num': 33,
#    'vid_len': 473},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id56_0009.mp4',
#    'split_num': 21,
#    'vid_len': 297},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id54_0007.mp4',
#    'split_num': 40,
#    'vid_len': 571},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id37_0005.mp4',
#    'split_num': 32,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id29_0008.mp4',
#    'split_num': 32,
#    'vid_len': 450},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id43_0006.mp4',
#    'split_num': 22,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id1_0006.mp4',
#    'split_num': 36,
#    'vid_len': 505},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id51_0001.mp4',
#    'split_num': 29,
#    'vid_len': 408},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id31_0007.mp4',
#    'split_num': 32,
#    'vid_len': 455},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id2_0003.mp4',
#    'split_num': 27,
#    'vid_len': 383},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id21_0009.mp4',
#    'split_num': 22,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id50_0003.mp4',
#    'split_num': 33,
#    'vid_len': 467},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id21_0006.mp4',
#    'split_num': 25,
#    'vid_len': 359},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id44_0003.mp4',
#    'split_num': 24,
#    'vid_len': 342},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id36_0006.mp4',
#    'split_num': 33,
#    'vid_len': 470},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id36_0008.mp4',
#    'split_num': 33,
#    'vid_len': 463},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id1_0008.mp4',
#    'split_num': 37,
#    'vid_len': 519},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id45_0003.mp4',
#    'split_num': 22,
#    'vid_len': 313},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id48_0003.mp4',
#    'split_num': 23,
#    'vid_len': 335},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id23_0001.mp4',
#    'split_num': 22,
#    'vid_len': 309},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id16_0010.mp4',
#    'split_num': 23,
#    'vid_len': 325},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id31_0004.mp4',
#    'split_num': 33,
#    'vid_len': 465},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id35_0000.mp4',
#    'split_num': 34,
#    'vid_len': 487},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id58_0002.mp4',
#    'split_num': 33,
#    'vid_len': 466},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id30_0007.mp4',
#    'split_num': 32,
#    'vid_len': 456},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id12_0005.mp4',
#    'split_num': 22,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id56_0002.mp4',
#    'split_num': 25,
#    'vid_len': 362},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id33_0005.mp4',
#    'split_num': 26,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id29_0009.mp4',
#    'split_num': 33,
#    'vid_len': 474},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id13_0013.mp4',
#    'split_num': 32,
#    'vid_len': 459},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id28_0009.mp4',
#    'split_num': 23,
#    'vid_len': 331},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id36_0000.mp4',
#    'split_num': 29,
#    'vid_len': 416},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id24_0009.mp4',
#    'split_num': 22,
#    'vid_len': 310},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id39_0004.mp4',
#    'split_num': 20,
#    'vid_len': 280},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id27_0008.mp4',
#    'split_num': 23,
#    'vid_len': 331},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id11_0006.mp4',
#    'split_num': 22,
#    'vid_len': 316},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id19_0007.mp4',
#    'split_num': 23,
#    'vid_len': 328},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id37_0009.mp4',
#    'split_num': 33,
#    'vid_len': 473},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id3_0008.mp4',
#    'split_num': 32,
#    'vid_len': 458},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id46_0000.mp4',
#    'split_num': 23,
#    'vid_len': 335},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id33_0008.mp4',
#    'split_num': 36,
#    'vid_len': 504},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id8_0000.mp4',
#    'split_num': 34,
#    'vid_len': 477},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id16_0007.mp4',
#    'split_num': 20,
#    'vid_len': 284},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id1_0001.mp4',
#    'split_num': 19,
#    'vid_len': 276},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id32_0002.mp4',
#    'split_num': 35,
#    'vid_len': 494},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id19_0005.mp4',
#    'split_num': 23,
#    'vid_len': 322},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id27_0009.mp4',
#    'split_num': 22,
#    'vid_len': 311},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id2_0001.mp4',
#    'split_num': 26,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id13_0011.mp4',
#    'split_num': 33,
#    'vid_len': 466},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id49_0004.mp4',
#    'split_num': 29,
#    'vid_len': 414},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id57_0007.mp4',
#    'split_num': 31,
#    'vid_len': 441},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id26_0008.mp4',
#    'split_num': 22,
#    'vid_len': 318},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id2_0004.mp4',
#    'split_num': 30,
#    'vid_len': 425},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id36_0001.mp4',
#    'split_num': 30,
#    'vid_len': 427},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id0_0001.mp4',
#    'split_num': 21,
#    'vid_len': 303},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id10_0007.mp4',
#    'split_num': 35,
#    'vid_len': 496},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id17_0002.mp4',
#    'split_num': 23,
#    'vid_len': 334},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id4_0004.mp4',
#    'split_num': 31,
#    'vid_len': 439},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id36_0002.mp4',
#    'split_num': 32,
#    'vid_len': 456},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id53_0003.mp4',
#    'split_num': 33,
#    'vid_len': 472},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id25_0010.mp4',
#    'split_num': 25,
#    'vid_len': 355},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id51_0006.mp4',
#    'split_num': 32,
#    'vid_len': 461},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id22_0000.mp4',
#    'split_num': 14,
#    'vid_len': 199},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id10_0001.mp4',
#    'split_num': 9,
#    'vid_len': 138},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id6_0002.mp4',
#    'split_num': 43,
#    'vid_len': 611},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id12_0000.mp4',
#    'split_num': 26,
#    'vid_len': 376},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id35_0003.mp4',
#    'split_num': 32,
#    'vid_len': 454},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id3_0002.mp4',
#    'split_num': 30,
#    'vid_len': 428},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id31_0003.mp4',
#    'split_num': 33,
#    'vid_len': 467},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id52_0002.mp4',
#    'split_num': 38,
#    'vid_len': 541},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id2_0002.mp4',
#    'split_num': 25,
#    'vid_len': 361},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id44_0001.mp4',
#    'split_num': 22,
#    'vid_len': 314},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id8_0009.mp4',
#    'split_num': 26,
#    'vid_len': 373},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id33_0002.mp4',
#    'split_num': 32,
#    'vid_len': 452},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id50_0000.mp4',
#    'split_num': 20,
#    'vid_len': 283},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id40_0003.mp4',
#    'split_num': 22,
#    'vid_len': 319},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id7_0006.mp4',
#    'split_num': 15,
#    'vid_len': 214},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id53_0007.mp4',
#    'split_num': 31,
#    'vid_len': 447},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id43_0002.mp4',
#    'split_num': 23,
#    'vid_len': 335},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id56_0000.mp4',
#    'split_num': 33,
#    'vid_len': 469},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id13_0004.mp4',
#    'split_num': 25,
#    'vid_len': 352},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id43_0001.mp4',
#    'split_num': 24,
#    'vid_len': 341},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id20_0008.mp4',
#    'split_num': 24,
#    'vid_len': 338},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id28_0004.mp4',
#    'split_num': 22,
#    'vid_len': 311},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id22_0009.mp4',
#    'split_num': 23,
#    'vid_len': 332},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id53_0000.mp4',
#    'split_num': 33,
#    'vid_len': 473},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id50_0006.mp4',
#    'split_num': 32,
#    'vid_len': 449},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id32_0003.mp4',
#    'split_num': 32,
#    'vid_len': 448},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id32_0006.mp4',
#    'split_num': 33,
#    'vid_len': 464},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id57_0003.mp4',
#    'split_num': 32,
#    'vid_len': 455},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id37_0004.mp4',
#    'split_num': 26,
#    'vid_len': 370},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id28_0007.mp4',
#    'split_num': 21,
#    'vid_len': 301},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id52_0001.mp4',
#    'split_num': 33,
#    'vid_len': 466},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id40_0009.mp4',
#    'split_num': 22,
#    'vid_len': 316},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id51_0005.mp4',
#    'split_num': 27,
#    'vid_len': 383},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id34_0006.mp4',
#    'split_num': 31,
#    'vid_len': 441},
#   {'path': '/home/kyr/GazeForensicsData/cropped_videos/CDF_crop/Celeb-real/id42_0002.mp4',
#    'split_num': 22,
#    'vid_len': 317}],
#  'len_per_vid': 14}

# %%
with open(rootDir + 'clip_info/CDF_vid_category_dict.json', 'w') as f:
    json.dump(CDF_vid_category_dict, f)

# %% [markdown]
# **FF++**

# %%
def gen_FF(quality:list, manip_types:list):
    if quality not in ['c23', 'c40']:
        print('Invalid Quality Type')
    for i in manip_types:
        if i not in ['Deepfakes', 'Face2Face', 'FaceSwap', 'NeuralTextures']:
            print('Invalid Manipulation Type')
    FF_vid_category_dict = {'fake_train': [], 'fake_test': [], 'real_train': None, 'real_test': None}
    # The json file used below is from https://github.com/ondyari/FaceForensics/tree/master/dataset/splits
    with open(rootDir + 'cropped_videos/FF++_crop/test.json', 'r') as f:
        FF_test_list = json.load(f)
        FF_test_list = [item for sublist in FF_test_list for item in sublist]
    with open(rootDir + 'cropped_videos/FF++_crop/train.json', 'r') as f:
        FF_train_list = json.load(f)
        FF_train_list = [item for sublist in FF_train_list for item in sublist]
    FF_crop_path = 'cropped_videos/FF++_crop/' + quality + '/'
    temp_vids_list = [rootDir + FF_crop_path + 'real/' + i for i in ls(rootDir + FF_crop_path + 'real/') if i[-4:] == '.mp4']
    FF_vid_category_dict['real_train'] = [vid for vid in temp_vids_list if vid.split('/')[-1][:-4] in FF_train_list]
    temp_vids_list = [rootDir + FF_crop_path + 'real/' + i for i in ls(rootDir + FF_crop_path + 'real/') if i[-4:] == '.mp4']
    FF_vid_category_dict['real_test'] = [vid for vid in temp_vids_list if vid.split('/')[-1][:-4] in FF_test_list]
    for manipulation_type in manip_types:
        temp_vids_list = [rootDir + FF_crop_path + 'fake/' + manipulation_type + '/' + i for i in ls(rootDir + FF_crop_path + 'fake/' + manipulation_type + '/') if i[-4:] == '.mp4']
        FF_vid_category_dict['fake_train'].extend([vid for vid in temp_vids_list if vid.split('/')[-1].split('_')[0] in FF_train_list])
        temp_vids_list = [rootDir + FF_crop_path + 'fake/' + manipulation_type + '/' + i for i in ls(rootDir + FF_crop_path + 'fake/' + manipulation_type + '/') if i[-4:] == '.mp4']
        FF_vid_category_dict['fake_test'].extend([vid for vid in temp_vids_list if vid.split('/')[-1].split('_')[0] in FF_test_list])
    
    FF_vid_category_dict = gen_clip_len_list(
        len_per_vid=14,
        vid_category_dict=FF_vid_category_dict,
        max_splits=36
    )
    
    with open(rootDir + 'clip_info/FF++_' + quality + (('_' + manip_types[0]) if len(manip_types)==1 else '') + '_vid_category_dict.json', 'w') as f:
        json.dump(FF_vid_category_dict, f)

# %% [markdown]
# c23

# %%
gen_FF('c23', ['Deepfakes', 'Face2Face', 'FaceSwap', 'NeuralTextures'])
# Out:
# split_num_dict before tweaking: {'fake_train': 83625, 'fake_test': 18814, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 21993, 'fake_test': 18814, 'real_train': 21993, 'real_test': 5208}

# %%
for manip_type in ['Deepfakes', 'Face2Face', 'FaceSwap', 'NeuralTextures']:
    gen_FF('c23', [manip_type])
# Out:
# split_num_dict before tweaking: {'fake_train': 21971, 'fake_test': 5208, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 21971, 'fake_test': 5208, 'real_train': 21971, 'real_test': 5208}
# split_num_dict before tweaking: {'fake_train': 21990, 'fake_test': 5208, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 21990, 'fake_test': 5208, 'real_train': 21990, 'real_test': 5208}
# split_num_dict before tweaking: {'fake_train': 19819, 'fake_test': 4198, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 19819, 'fake_test': 4198, 'real_train': 19819, 'real_test': 5208}
# split_num_dict before tweaking: {'fake_train': 19845, 'fake_test': 4200, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 19845, 'fake_test': 4200, 'real_train': 19845, 'real_test': 5208}

# %% [markdown]
# c40

# %%
gen_FF('c40', ['Deepfakes', 'Face2Face', 'FaceSwap', 'NeuralTextures'])
# Out:
# split_num_dict before tweaking: {'fake_train': 83625, 'fake_test': 18814, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 21993, 'fake_test': 18814, 'real_train': 21993, 'real_test': 5208}

# %%
for manip_type in ['Deepfakes', 'Face2Face', 'FaceSwap', 'NeuralTextures']:
    gen_FF('c40', [manip_type])
# Out:
# split_num_dict before tweaking: {'fake_train': 21971, 'fake_test': 5208, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 21971, 'fake_test': 5208, 'real_train': 21971, 'real_test': 5208}
# split_num_dict before tweaking: {'fake_train': 21990, 'fake_test': 5208, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 21990, 'fake_test': 5208, 'real_train': 21990, 'real_test': 5208}
# split_num_dict before tweaking: {'fake_train': 19819, 'fake_test': 4198, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 19819, 'fake_test': 4198, 'real_train': 19819, 'real_test': 5208}
# split_num_dict before tweaking: {'fake_train': 19845, 'fake_test': 4200, 'real_train': 21993, 'real_test': 5208}
# split_num_dict after tweaking: {'fake_train': 19845, 'fake_test': 4200, 'real_train': 19845, 'real_test': 5208}

# %% [markdown]
# **WDF**

# %%
WDF_vid_category_dict = {'fake_train': None, 'fake_test': None, 'real_train': None, 'real_test': None}
temp_dir = rootDir + 'cropped_videos/WDF_crop/'
WDF_vid_category_dict['fake_train'] = [temp_dir + 'fake_train/' + i for i in fileWalk(temp_dir + 'fake_train/') if i[-4:] == '.mp4']
WDF_vid_category_dict['fake_test'] = [temp_dir + 'fake_test/' + i for i in fileWalk(temp_dir + 'fake_test/') if i[-4:] == '.mp4']
WDF_vid_category_dict['real_train'] = [temp_dir + 'real_train/' + i for i in fileWalk(temp_dir + 'real_train/') if i[-4:] == '.mp4']
WDF_vid_category_dict['real_test'] = [temp_dir + 'real_test/' + i for i in fileWalk(temp_dir + 'real_test/') if i[-4:] == '.mp4']

# %%
WDF_vid_category_dict = gen_clip_len_list(
    len_per_vid=14,
    vid_category_dict=WDF_vid_category_dict,
    max_splits=None
)
# Out:
# split_num_dict before tweaking: {'fake_train': 43739, 'fake_test': 7452, 'real_train': 25675, 'real_test': 3999}
# split_num_dict after tweaking: {'fake_train': 25675, 'fake_test': 7452, 'real_train': 25675, 'real_test': 3999}

# %%
display_category_dict_info(WDF_vid_category_dict)
# Out:
# Fake Train:
# 	vid_len:
# 		min: 51
# 		max: 29008
# 		mean: 204.12
# 		median: 125
# 	split_num:
# 		min: 3
# 		max: 12
# 		mean: 8.28
# 		median: 8
# Fake Test:
# 	vid_len:
# 		min: 52
# 		max: 3418
# 		mean: 260.98
# 		median: 144
# 	split_num:
# 		min: 3
# 		max: 244
# 		mean: 18.18
# 		median: 10
# Real Train:
# 	vid_len:
# 		min: 51
# 		max: 3572
# 		mean: 112.02
# 		median: 85
# 	split_num:
# 		min: 3
# 		max: 255
# 		mean: 7.53
# 		median: 6
# Real Test:
# 	vid_len:
# 		min: 51
# 		max: 3655
# 		mean: 148.13
# 		median: 86
# 	split_num:
# 		min: 3
# 		max: 261
# 		mean: 10.1
# 		median: 6

# %% [markdown]
# ---
#
# Found that the Wilddeepfake dataset has some very long videos that took too much splits
#
# So set the `max_splits` to the mean of real_train's split_num
#
# ---

# %%
WDF_vid_category_dict = {'fake_train': None, 'fake_test': None, 'real_train': None, 'real_test': None}
temp_dir = rootDir + 'cropped_videos/WDF_crop/'
WDF_vid_category_dict['fake_train'] = [temp_dir + 'fake_train/' + i for i in fileWalk(temp_dir + 'fake_train/') if i[-4:] == '.mp4']
WDF_vid_category_dict['fake_test'] = [temp_dir + 'fake_test/' + i for i in fileWalk(temp_dir + 'fake_test/') if i[-4:] == '.mp4']
WDF_vid_category_dict['real_train'] = [temp_dir + 'real_train/' + i for i in fileWalk(temp_dir + 'real_train/') if i[-4:] == '.mp4']
WDF_vid_category_dict['real_test'] = [temp_dir + 'real_test/' + i for i in fileWalk(temp_dir + 'real_test/') if i[-4:] == '.mp4']

# %%
WDF_vid_category_dict = gen_clip_len_list(
    len_per_vid=14,
    vid_category_dict=WDF_vid_category_dict,
    max_splits=8
)
# Out:
# split_num_dict before tweaking: {'fake_train': 21426, 'fake_test': 7452, 'real_train': 19736, 'real_test': 3999}
# split_num_dict after tweaking: {'fake_train': 19736, 'fake_test': 7452, 'real_train': 19736, 'real_test': 3999}

# %%
display_category_dict_info(WDF_vid_category_dict)
# Out:
# Fake Train:
# 	vid_len:
# 		min: 51
# 		max: 29008
# 		mean: 204.12
# 		median: 125
# 	split_num:
# 		min: 3
# 		max: 8
# 		mean: 6.37
# 		median: 7
# Fake Test:
# 	vid_len:
# 		min: 52
# 		max: 3418
# 		mean: 260.98
# 		median: 144
# 	split_num:
# 		min: 3
# 		max: 244
# 		mean: 18.18
# 		median: 10
# Real Train:
# 	vid_len:
# 		min: 51
# 		max: 3572
# 		mean: 112.02
# 		median: 85
# 	split_num:
# 		min: 3
# 		max: 8
# 		mean: 5.79
# 		median: 6
# Real Test:
# 	vid_len:
# 		min: 51
# 		max: 3655
# 		mean: 148.13
# 		median: 86
# 	split_num:
# 		min: 3
# 		max: 261
# 		mean: 10.1
# 		median: 6

# %%
WDF_vid_category_dict[list(WDF_vid_category_dict.keys())[1]]
# Out:
# [{'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/81_24.mp4',
#   'split_num': 11,
#   'vid_len': 157},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_432.mp4',
#   'split_num': 4,
#   'vid_len': 58},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/79_184.mp4',
#   'split_num': 12,
#   'vid_len': 178},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/62_170.mp4',
#   'split_num': 15,
#   'vid_len': 215},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/44_40.mp4',
#   'split_num': 25,
#   'vid_len': 362},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/33_0.mp4',
#   'split_num': 9,
#   'vid_len': 134},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/35_2.mp4',
#   'split_num': 51,
#   'vid_len': 719},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/52_23.mp4',
#   'split_num': 20,
#   'vid_len': 289},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/33_330.mp4',
#   'split_num': 5,
#   'vid_len': 72},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/11_2.mp4',
#   'split_num': 60,
#   'vid_len': 851},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/63_37.mp4',
#   'split_num': 11,
#   'vid_len': 165},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/13_2.mp4',
#   'split_num': 4,
#   'vid_len': 66},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/18_28.mp4',
#   'split_num': 10,
#   'vid_len': 140},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/14_40.mp4',
#   'split_num': 10,
#   'vid_len': 140},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/73_8.mp4',
#   'split_num': 7,
#   'vid_len': 103},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/16_180.mp4',
#   'split_num': 9,
#   'vid_len': 132},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/66_7.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/54_79.mp4',
#   'split_num': 144,
#   'vid_len': 2027},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/50_19.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/39_5.mp4',
#   'split_num': 7,
#   'vid_len': 102},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/68_7.mp4',
#   'split_num': 13,
#   'vid_len': 194},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_388.mp4',
#   'split_num': 4,
#   'vid_len': 67},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_170.mp4',
#   'split_num': 4,
#   'vid_len': 63},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/16_190.mp4',
#   'split_num': 6,
#   'vid_len': 97},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/52_4.mp4',
#   'split_num': 6,
#   'vid_len': 92},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/26_49.mp4',
#   'split_num': 25,
#   'vid_len': 360},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/3_120.mp4',
#   'split_num': 6,
#   'vid_len': 93},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/95_66.mp4',
#   'split_num': 3,
#   'vid_len': 55},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/25_80.mp4',
#   'split_num': 13,
#   'vid_len': 194},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/61_20.mp4',
#   'split_num': 6,
#   'vid_len': 90},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/90_27.mp4',
#   'split_num': 14,
#   'vid_len': 197},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/107_1.mp4',
#   'split_num': 18,
#   'vid_len': 262},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/88_0.mp4',
#   'split_num': 108,
#   'vid_len': 1516},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_713.mp4',
#   'split_num': 33,
#   'vid_len': 472},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/60_4.mp4',
#   'split_num': 5,
#   'vid_len': 80},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/38_406.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_220.mp4',
#   'split_num': 114,
#   'vid_len': 1602},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/26_87.mp4',
#   'split_num': 4,
#   'vid_len': 56},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/13_0.mp4',
#   'split_num': 244,
#   'vid_len': 3418},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/16_193.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/9_84.mp4',
#   'split_num': 6,
#   'vid_len': 92},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/72_72.mp4',
#   'split_num': 7,
#   'vid_len': 100},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/70_69.mp4',
#   'split_num': 14,
#   'vid_len': 202},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/87_25.mp4',
#   'split_num': 11,
#   'vid_len': 159},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/83_242.mp4',
#   'split_num': 8,
#   'vid_len': 113},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/106_11.mp4',
#   'split_num': 13,
#   'vid_len': 193},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/73_1850.mp4',
#   'split_num': 13,
#   'vid_len': 187},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/90_18.mp4',
#   'split_num': 10,
#   'vid_len': 141},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/50_41.mp4',
#   'split_num': 11,
#   'vid_len': 165},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/91_4.mp4',
#   'split_num': 7,
#   'vid_len': 101},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/33_28.mp4',
#   'split_num': 12,
#   'vid_len': 170},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/29_349.mp4',
#   'split_num': 7,
#   'vid_len': 106},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/36_11.mp4',
#   'split_num': 28,
#   'vid_len': 397},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/50_0.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/49_4.mp4',
#   'split_num': 12,
#   'vid_len': 168},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/2_79.mp4',
#   'split_num': 4,
#   'vid_len': 65},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/41_4.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/49_35.mp4',
#   'split_num': 17,
#   'vid_len': 238},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/14_38.mp4',
#   'split_num': 6,
#   'vid_len': 91},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/19_103.mp4',
#   'split_num': 21,
#   'vid_len': 301},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/66_100.mp4',
#   'split_num': 6,
#   'vid_len': 93},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/94_26.mp4',
#   'split_num': 9,
#   'vid_len': 137},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/98_132.mp4',
#   'split_num': 18,
#   'vid_len': 255},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/72_228.mp4',
#   'split_num': 8,
#   'vid_len': 116},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/94_28.mp4',
#   'split_num': 13,
#   'vid_len': 195},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/35_1.mp4',
#   'split_num': 31,
#   'vid_len': 440},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/52_0.mp4',
#   'split_num': 13,
#   'vid_len': 183},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/91_31.mp4',
#   'split_num': 10,
#   'vid_len': 144},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/72_277.mp4',
#   'split_num': 8,
#   'vid_len': 113},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/38_195.mp4',
#   'split_num': 15,
#   'vid_len': 215},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/14_76.mp4',
#   'split_num': 8,
#   'vid_len': 119},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_128.mp4',
#   'split_num': 5,
#   'vid_len': 82},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/15_16.mp4',
#   'split_num': 11,
#   'vid_len': 155},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/17_33.mp4',
#   'split_num': 20,
#   'vid_len': 293},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/40_4.mp4',
#   'split_num': 43,
#   'vid_len': 608},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/67_12.mp4',
#   'split_num': 8,
#   'vid_len': 112},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/51_0.mp4',
#   'split_num': 11,
#   'vid_len': 157},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/31_28.mp4',
#   'split_num': 26,
#   'vid_len': 369},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/38_92.mp4',
#   'split_num': 10,
#   'vid_len': 150},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/8_199.mp4',
#   'split_num': 7,
#   'vid_len': 99},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_181.mp4',
#   'split_num': 4,
#   'vid_len': 64},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/87_28.mp4',
#   'split_num': 10,
#   'vid_len': 145},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/85_219.mp4',
#   'split_num': 10,
#   'vid_len': 141},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/30_0.mp4',
#   'split_num': 34,
#   'vid_len': 480},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/63_93.mp4',
#   'split_num': 7,
#   'vid_len': 108},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/69_16.mp4',
#   'split_num': 28,
#   'vid_len': 393},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/36_43.mp4',
#   'split_num': 11,
#   'vid_len': 163},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/15_147.mp4',
#   'split_num': 13,
#   'vid_len': 183},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/24_14.mp4',
#   'split_num': 17,
#   'vid_len': 242},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/20_30.mp4',
#   'split_num': 3,
#   'vid_len': 52},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/98_222.mp4',
#   'split_num': 10,
#   'vid_len': 153},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/67_15.mp4',
#   'split_num': 9,
#   'vid_len': 128},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/102_0.mp4',
#   'split_num': 7,
#   'vid_len': 111},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/26_48.mp4',
#   'split_num': 20,
#   'vid_len': 290},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/6_553.mp4',
#   'split_num': 6,
#   'vid_len': 96},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/45_21.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/25_75.mp4',
#   'split_num': 12,
#   'vid_len': 177},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/115_546.mp4',
#   'split_num': 7,
#   'vid_len': 106},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/8_168.mp4',
#   'split_num': 4,
#   'vid_len': 65},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/91_33.mp4',
#   'split_num': 6,
#   'vid_len': 90},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/61_93.mp4',
#   'split_num': 6,
#   'vid_len': 91},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/22_3.mp4',
#   'split_num': 93,
#   'vid_len': 1307},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/105_90.mp4',
#   'split_num': 9,
#   'vid_len': 127},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/47_1.mp4',
#   'split_num': 22,
#   'vid_len': 319},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/68_0.mp4',
#   'split_num': 26,
#   'vid_len': 366},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/110_0.mp4',
#   'split_num': 45,
#   'vid_len': 638},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/113_9.mp4',
#   'split_num': 8,
#   'vid_len': 121},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/70_1.mp4',
#   'split_num': 6,
#   'vid_len': 97},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/94_6.mp4',
#   'split_num': 8,
#   'vid_len': 116},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/86_350.mp4',
#   'split_num': 13,
#   'vid_len': 193},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/1_40.mp4',
#   'split_num': 22,
#   'vid_len': 314},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_87.mp4',
#   'split_num': 5,
#   'vid_len': 74},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/71_25.mp4',
#   'split_num': 13,
#   'vid_len': 186},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/46_1.mp4',
#   'split_num': 104,
#   'vid_len': 1461},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/81_77.mp4',
#   'split_num': 30,
#   'vid_len': 420},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/95_70.mp4',
#   'split_num': 4,
#   'vid_len': 56},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/63_53.mp4',
#   'split_num': 18,
#   'vid_len': 261},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/31_43.mp4',
#   'split_num': 20,
#   'vid_len': 286},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/23_38.mp4',
#   'split_num': 9,
#   'vid_len': 127},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/59_51.mp4',
#   'split_num': 7,
#   'vid_len': 100},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/31_6.mp4',
#   'split_num': 11,
#   'vid_len': 162},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/42_12.mp4',
#   'split_num': 17,
#   'vid_len': 239},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/37_133.mp4',
#   'split_num': 19,
#   'vid_len': 267},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_893.mp4',
#   'split_num': 5,
#   'vid_len': 74},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/36_0.mp4',
#   'split_num': 29,
#   'vid_len': 408},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/78_145.mp4',
#   'split_num': 11,
#   'vid_len': 155},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/43_21.mp4',
#   'split_num': 16,
#   'vid_len': 233},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/79_178.mp4',
#   'split_num': 7,
#   'vid_len': 104},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/64_25.mp4',
#   'split_num': 29,
#   'vid_len': 406},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/107_90.mp4',
#   'split_num': 6,
#   'vid_len': 90},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/44_662.mp4',
#   'split_num': 6,
#   'vid_len': 93},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/43_7.mp4',
#   'split_num': 10,
#   'vid_len': 144},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/104_48.mp4',
#   'split_num': 10,
#   'vid_len': 143},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/12_70.mp4',
#   'split_num': 9,
#   'vid_len': 137},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/83_437.mp4',
#   'split_num': 15,
#   'vid_len': 217},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/96_181.mp4',
#   'split_num': 6,
#   'vid_len': 91},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/43_30.mp4',
#   'split_num': 9,
#   'vid_len': 138},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_208.mp4',
#   'split_num': 5,
#   'vid_len': 70},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/98_314.mp4',
#   'split_num': 11,
#   'vid_len': 164},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_28.mp4',
#   'split_num': 5,
#   'vid_len': 76},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/104_30.mp4',
#   'split_num': 6,
#   'vid_len': 97},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/3_60.mp4',
#   'split_num': 12,
#   'vid_len': 179},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/76_0.mp4',
#   'split_num': 210,
#   'vid_len': 2950},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/66_91.mp4',
#   'split_num': 7,
#   'vid_len': 102},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/62_166.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/12_53.mp4',
#   'split_num': 13,
#   'vid_len': 185},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/53_73.mp4',
#   'split_num': 7,
#   'vid_len': 100},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/105_1.mp4',
#   'split_num': 12,
#   'vid_len': 171},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/85_37.mp4',
#   'split_num': 18,
#   'vid_len': 262},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/95_140.mp4',
#   'split_num': 6,
#   'vid_len': 94},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/83_433.mp4',
#   'split_num': 11,
#   'vid_len': 158},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/65_4.mp4',
#   'split_num': 14,
#   'vid_len': 200},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/79_160.mp4',
#   'split_num': 24,
#   'vid_len': 341},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/114_0.mp4',
#   'split_num': 24,
#   'vid_len': 346},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/8_183.mp4',
#   'split_num': 4,
#   'vid_len': 57},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/105_116.mp4',
#   'split_num': 11,
#   'vid_len': 166},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/11_5.mp4',
#   'split_num': 14,
#   'vid_len': 204},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/69_14.mp4',
#   'split_num': 14,
#   'vid_len': 196},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/108_11.mp4',
#   'split_num': 10,
#   'vid_len': 144},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/74_101.mp4',
#   'split_num': 7,
#   'vid_len': 103},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/57_0.mp4',
#   'split_num': 25,
#   'vid_len': 363},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/37_204.mp4',
#   'split_num': 24,
#   'vid_len': 337},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/80_0.mp4',
#   'split_num': 10,
#   'vid_len': 142},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/45_16.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/112_6.mp4',
#   'split_num': 14,
#   'vid_len': 205},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/78_21.mp4',
#   'split_num': 8,
#   'vid_len': 125},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/43_2.mp4',
#   'split_num': 7,
#   'vid_len': 109},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/65_1.mp4',
#   'split_num': 29,
#   'vid_len': 409},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/53_4.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_5.mp4',
#   'split_num': 4,
#   'vid_len': 67},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/82_33.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/41_0.mp4',
#   'split_num': 36,
#   'vid_len': 508},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/45_14.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/45_28.mp4',
#   'split_num': 7,
#   'vid_len': 109},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/26_91.mp4',
#   'split_num': 8,
#   'vid_len': 119},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/49_11.mp4',
#   'split_num': 9,
#   'vid_len': 126},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/29_9.mp4',
#   'split_num': 15,
#   'vid_len': 211},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/36_45.mp4',
#   'split_num': 9,
#   'vid_len': 133},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/108_0.mp4',
#   'split_num': 3,
#   'vid_len': 53},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/44_424.mp4',
#   'split_num': 10,
#   'vid_len': 147},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/103_0.mp4',
#   'split_num': 31,
#   'vid_len': 441},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/61_16.mp4',
#   'split_num': 6,
#   'vid_len': 96},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/82_14.mp4',
#   'split_num': 7,
#   'vid_len': 108},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/58_25.mp4',
#   'split_num': 15,
#   'vid_len': 213},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/102_30.mp4',
#   'split_num': 7,
#   'vid_len': 107},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/55_28.mp4',
#   'split_num': 7,
#   'vid_len': 99},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/87_1.mp4',
#   'split_num': 19,
#   'vid_len': 266},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/90_0.mp4',
#   'split_num': 6,
#   'vid_len': 90},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_315.mp4',
#   'split_num': 5,
#   'vid_len': 82},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/56_0.mp4',
#   'split_num': 151,
#   'vid_len': 2120},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/58_101.mp4',
#   'split_num': 6,
#   'vid_len': 91},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/80_3.mp4',
#   'split_num': 3,
#   'vid_len': 52},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/85_177.mp4',
#   'split_num': 14,
#   'vid_len': 200},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/30_9.mp4',
#   'split_num': 53,
#   'vid_len': 755},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/22_0.mp4',
#   'split_num': 60,
#   'vid_len': 847},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/16_197.mp4',
#   'split_num': 7,
#   'vid_len': 111},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/109_0.mp4',
#   'split_num': 35,
#   'vid_len': 492},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/79_9.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/40_2.mp4',
#   'split_num': 28,
#   'vid_len': 397},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/74_279.mp4',
#   'split_num': 8,
#   'vid_len': 123},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/18_189.mp4',
#   'split_num': 13,
#   'vid_len': 195},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_48.mp4',
#   'split_num': 5,
#   'vid_len': 74},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/69_144.mp4',
#   'split_num': 11,
#   'vid_len': 161},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/97_32.mp4',
#   'split_num': 6,
#   'vid_len': 86},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/70_37.mp4',
#   'split_num': 28,
#   'vid_len': 405},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/94_8.mp4',
#   'split_num': 15,
#   'vid_len': 215},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/58_50.mp4',
#   'split_num': 10,
#   'vid_len': 142},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/81_2.mp4',
#   'split_num': 6,
#   'vid_len': 97},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/63_0.mp4',
#   'split_num': 7,
#   'vid_len': 100},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/74_19.mp4',
#   'split_num': 8,
#   'vid_len': 114},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/37_34.mp4',
#   'split_num': 7,
#   'vid_len': 98},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/62_6.mp4',
#   'split_num': 13,
#   'vid_len': 187},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/37_10.mp4',
#   'split_num': 6,
#   'vid_len': 97},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/8_148.mp4',
#   'split_num': 6,
#   'vid_len': 85},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_394.mp4',
#   'split_num': 4,
#   'vid_len': 67},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/104_46.mp4',
#   'split_num': 14,
#   'vid_len': 198},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/28_714.mp4',
#   'split_num': 19,
#   'vid_len': 273},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/81_98.mp4',
#   'split_num': 15,
#   'vid_len': 218},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/29_323.mp4',
#   'split_num': 7,
#   'vid_len': 99},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_313.mp4',
#   'split_num': 4,
#   'vid_len': 62},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/65_13.mp4',
#   'split_num': 19,
#   'vid_len': 268},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/49_93.mp4',
#   'split_num': 21,
#   'vid_len': 297},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/74_242.mp4',
#   'split_num': 8,
#   'vid_len': 116},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/4_183.mp4',
#   'split_num': 5,
#   'vid_len': 71},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/52_21.mp4',
#   'split_num': 18,
#   'vid_len': 256},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/49_10.mp4',
#   'split_num': 9,
#   'vid_len': 126},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/51_8.mp4',
#   'split_num': 5,
#   'vid_len': 78},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/60_0.mp4',
#   'split_num': 11,
#   'vid_len': 164},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/3_14.mp4',
#   'split_num': 8,
#   'vid_len': 115},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/27_1.mp4',
#   'split_num': 73,
#   'vid_len': 1034},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/51_9.mp4',
#   'split_num': 28,
#   'vid_len': 392},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/67_0.mp4',
#   'split_num': 22,
#   'vid_len': 308},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/21_0.mp4',
#   'split_num': 106,
#   'vid_len': 1486},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/40_5.mp4',
#   'split_num': 32,
#   'vid_len': 452},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/15_132.mp4',
#   'split_num': 8,
#   'vid_len': 121},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/108_9.mp4',
#   'split_num': 11,
#   'vid_len': 159},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/106_13.mp4',
#   'split_num': 7,
#   'vid_len': 107},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/67_20.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/12_144.mp4',
#   'split_num': 12,
#   'vid_len': 175},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/112_19.mp4',
#   'split_num': 12,
#   'vid_len': 175},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_646.mp4',
#   'split_num': 41,
#   'vid_len': 578},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/62_19.mp4',
#   'split_num': 8,
#   'vid_len': 115},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/107_31.mp4',
#   'split_num': 8,
#   'vid_len': 112},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/43_22.mp4',
#   'split_num': 8,
#   'vid_len': 112},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/19_69.mp4',
#   'split_num': 8,
#   'vid_len': 119},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/112_417.mp4',
#   'split_num': 10,
#   'vid_len': 152},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/2_43.mp4',
#   'split_num': 16,
#   'vid_len': 234},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/92_2.mp4',
#   'split_num': 12,
#   'vid_len': 171},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/82_15.mp4',
#   'split_num': 7,
#   'vid_len': 108},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/25_6.mp4',
#   'split_num': 10,
#   'vid_len': 140},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/88_33.mp4',
#   'split_num': 7,
#   'vid_len': 99},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/25_22.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/36_46.mp4',
#   'split_num': 14,
#   'vid_len': 203},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/92_174.mp4',
#   'split_num': 11,
#   'vid_len': 166},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/74_195.mp4',
#   'split_num': 14,
#   'vid_len': 197},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/72_189.mp4',
#   'split_num': 6,
#   'vid_len': 97},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/24_60.mp4',
#   'split_num': 18,
#   'vid_len': 265},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/107_66.mp4',
#   'split_num': 6,
#   'vid_len': 94},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_822.mp4',
#   'split_num': 42,
#   'vid_len': 591},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/82_31.mp4',
#   'split_num': 9,
#   'vid_len': 129},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/5_235.mp4',
#   'split_num': 4,
#   'vid_len': 60},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/6_795.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/111_1.mp4',
#   'split_num': 154,
#   'vid_len': 2160},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/70_109.mp4',
#   'split_num': 32,
#   'vid_len': 449},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/98_187.mp4',
#   'split_num': 8,
#   'vid_len': 118},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/113_12.mp4',
#   'split_num': 12,
#   'vid_len': 170},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/37_127.mp4',
#   'split_num': 6,
#   'vid_len': 92},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/79_20.mp4',
#   'split_num': 29,
#   'vid_len': 411},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/19_29.mp4',
#   'split_num': 10,
#   'vid_len': 149},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/104_64.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/93_81.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/44_183.mp4',
#   'split_num': 26,
#   'vid_len': 374},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/72_152.mp4',
#   'split_num': 7,
#   'vid_len': 102},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/34_32.mp4',
#   'split_num': 6,
#   'vid_len': 85},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/12_243.mp4',
#   'split_num': 8,
#   'vid_len': 116},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/2_50.mp4',
#   'split_num': 5,
#   'vid_len': 74},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/85_77.mp4',
#   'split_num': 21,
#   'vid_len': 306},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/38_87.mp4',
#   'split_num': 8,
#   'vid_len': 113},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/73_861.mp4',
#   'split_num': 6,
#   'vid_len': 92},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/99_0.mp4',
#   'split_num': 56,
#   'vid_len': 791},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/113_6.mp4',
#   'split_num': 6,
#   'vid_len': 93},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/38_5.mp4',
#   'split_num': 16,
#   'vid_len': 225},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/105_18.mp4',
#   'split_num': 12,
#   'vid_len': 181},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/48_96.mp4',
#   'split_num': 32,
#   'vid_len': 449},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/10_64.mp4',
#   'split_num': 9,
#   'vid_len': 139},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/53_38.mp4',
#   'split_num': 8,
#   'vid_len': 125},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/53_5.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/61_57.mp4',
#   'split_num': 29,
#   'vid_len': 413},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/55_24.mp4',
#   'split_num': 16,
#   'vid_len': 233},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/70_39.mp4',
#   'split_num': 14,
#   'vid_len': 202},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/93_103.mp4',
#   'split_num': 9,
#   'vid_len': 138},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/102_25.mp4',
#   'split_num': 16,
#   'vid_len': 232},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/24_207.mp4',
#   'split_num': 17,
#   'vid_len': 246},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/50_24.mp4',
#   'split_num': 10,
#   'vid_len': 153},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/75_0.mp4',
#   'split_num': 109,
#   'vid_len': 1527},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/12_1.mp4',
#   'split_num': 10,
#   'vid_len': 149},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/44_174.mp4',
#   'split_num': 7,
#   'vid_len': 106},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/65_0.mp4',
#   'split_num': 16,
#   'vid_len': 234},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/67_17.mp4',
#   'split_num': 6,
#   'vid_len': 90},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/86_3.mp4',
#   'split_num': 17,
#   'vid_len': 242},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/93_125.mp4',
#   'split_num': 7,
#   'vid_len': 105},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/53_34.mp4',
#   'split_num': 7,
#   'vid_len': 100},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/28_13.mp4',
#   'split_num': 8,
#   'vid_len': 112},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/54_74.mp4',
#   'split_num': 91,
#   'vid_len': 1281},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/58_0.mp4',
#   'split_num': 13,
#   'vid_len': 192},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/22_1.mp4',
#   'split_num': 43,
#   'vid_len': 603},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/105_0.mp4',
#   'split_num': 7,
#   'vid_len': 111},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/92_93.mp4',
#   'split_num': 10,
#   'vid_len': 152},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/111_2.mp4',
#   'split_num': 222,
#   'vid_len': 3117},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/101_144.mp4',
#   'split_num': 4,
#   'vid_len': 58},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/71_175.mp4',
#   'split_num': 6,
#   'vid_len': 91},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/35_0.mp4',
#   'split_num': 149,
#   'vid_len': 2093},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/78_165.mp4',
#   'split_num': 11,
#   'vid_len': 165},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_166.mp4',
#   'split_num': 6,
#   'vid_len': 86},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/32_168.mp4',
#   'split_num': 4,
#   'vid_len': 64},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/66_6.mp4',
#   'split_num': 10,
#   'vid_len': 141},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/24_155.mp4',
#   'split_num': 7,
#   'vid_len': 109},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/29_92.mp4',
#   'split_num': 27,
#   'vid_len': 380},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/86_91.mp4',
#   'split_num': 15,
#   'vid_len': 216},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/102_5.mp4',
#   'split_num': 4,
#   'vid_len': 68},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/31_41.mp4',
#   'split_num': 8,
#   'vid_len': 116},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/65_2.mp4',
#   'split_num': 10,
#   'vid_len': 142},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/108_1.mp4',
#   'split_num': 5,
#   'vid_len': 79},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/3_34.mp4',
#   'split_num': 10,
#   'vid_len': 141},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/45_11.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/1_1.mp4',
#   'split_num': 26,
#   'vid_len': 374},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/7_0.mp4',
#   'split_num': 58,
#   'vid_len': 817},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/47_11.mp4',
#   'split_num': 97,
#   'vid_len': 1364},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/59_62.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/100_0.mp4',
#   'split_num': 30,
#   'vid_len': 431},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/82_11.mp4',
#   'split_num': 7,
#   'vid_len': 103},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/112_462.mp4',
#   'split_num': 16,
#   'vid_len': 229},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/62_45.mp4',
#   'split_num': 14,
#   'vid_len': 199},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/66_106.mp4',
#   'split_num': 10,
#   'vid_len': 143},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/18_75.mp4',
#   'split_num': 7,
#   'vid_len': 108},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/20_2.mp4',
#   'split_num': 6,
#   'vid_len': 92},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/26_0.mp4',
#   'split_num': 4,
#   'vid_len': 66},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/73_1235.mp4',
#   'split_num': 10,
#   'vid_len': 148},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/40_1.mp4',
#   'split_num': 21,
#   'vid_len': 294},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/92_17.mp4',
#   'split_num': 12,
#   'vid_len': 181},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/68_10.mp4',
#   'split_num': 6,
#   'vid_len': 89},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/27_31.mp4',
#   'split_num': 54,
#   'vid_len': 766},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/5_189.mp4',
#   'split_num': 5,
#   'vid_len': 81},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/11_0.mp4',
#   'split_num': 23,
#   'vid_len': 334},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/29_15.mp4',
#   'split_num': 12,
#   'vid_len': 171},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/50_29.mp4',
#   'split_num': 18,
#   'vid_len': 264},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/14_0.mp4',
#   'split_num': 15,
#   'vid_len': 212},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/5_150.mp4',
#   'split_num': 3,
#   'vid_len': 55},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/23_91.mp4',
#   'split_num': 6,
#   'vid_len': 96},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/23_37.mp4',
#   'split_num': 9,
#   'vid_len': 137},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/34_26.mp4',
#   'split_num': 6,
#   'vid_len': 94},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/92_130.mp4',
#   'split_num': 9,
#   'vid_len': 127},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/106_0.mp4',
#   'split_num': 11,
#   'vid_len': 157},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/104_8.mp4',
#   'split_num': 11,
#   'vid_len': 158},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/1_33.mp4',
#   'split_num': 23,
#   'vid_len': 328},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/47_10.mp4',
#   'split_num': 22,
#   'vid_len': 311},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/59_55.mp4',
#   'split_num': 7,
#   'vid_len': 99},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/73_1209.mp4',
#   'split_num': 10,
#   'vid_len': 141},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/18_66.mp4',
#   'split_num': 10,
#   'vid_len': 150},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/83_435.mp4',
#   'split_num': 31,
#   'vid_len': 445},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/84_18.mp4',
#   'split_num': 5,
#   'vid_len': 77},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/77_1.mp4',
#   'split_num': 69,
#   'vid_len': 975},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/42_34.mp4',
#   'split_num': 4,
#   'vid_len': 67},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/55_0.mp4',
#   'split_num': 11,
#   'vid_len': 163},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/14_11.mp4',
#   'split_num': 8,
#   'vid_len': 112},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/23_77.mp4',
#   'split_num': 8,
#   'vid_len': 122},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/23_99.mp4',
#   'split_num': 11,
#   'vid_len': 165},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/10_95.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/68_6.mp4',
#   'split_num': 8,
#   'vid_len': 118},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/28_27.mp4',
#   'split_num': 10,
#   'vid_len': 146},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/69_10.mp4',
#   'split_num': 10,
#   'vid_len': 150},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/107_104.mp4',
#   'split_num': 12,
#   'vid_len': 174},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/64_1.mp4',
#   'split_num': 44,
#   'vid_len': 617},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/51_7.mp4',
#   'split_num': 8,
#   'vid_len': 124},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/98_47.mp4',
#   'split_num': 8,
#   'vid_len': 118},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/103_2.mp4',
#   'split_num': 9,
#   'vid_len': 136},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/63_21.mp4',
#   'split_num': 11,
#   'vid_len': 154},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/58_62.mp4',
#   'split_num': 23,
#   'vid_len': 335},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/85_102.mp4',
#   'split_num': 11,
#   'vid_len': 167},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/112_463.mp4',
#   'split_num': 8,
#   'vid_len': 119},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/78_23.mp4',
#   'split_num': 9,
#   'vid_len': 133},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/47_9.mp4',
#   'split_num': 37,
#   'vid_len': 521},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/103_8.mp4',
#   'split_num': 7,
#   'vid_len': 108},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/2_52.mp4',
#   'split_num': 9,
#   'vid_len': 131},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/78_34.mp4',
#   'split_num': 29,
#   'vid_len': 408},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/1_17.mp4',
#   'split_num': 9,
#   'vid_len': 137},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/95_73.mp4',
#   'split_num': 7,
#   'vid_len': 107},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/17_23.mp4',
#   'split_num': 25,
#   'vid_len': 352},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/24_62.mp4',
#   'split_num': 11,
#   'vid_len': 163},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/103_6.mp4',
#   'split_num': 15,
#   'vid_len': 210},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/93_75.mp4',
#   'split_num': 9,
#   'vid_len': 135},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/84_27.mp4',
#   'split_num': 36,
#   'vid_len': 506},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/94_29.mp4',
#   'split_num': 12,
#   'vid_len': 169},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/89_0.mp4',
#   'split_num': 91,
#   'vid_len': 1284},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/9_457.mp4',
#   'split_num': 14,
#   'vid_len': 208},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/59_63.mp4',
#   'split_num': 6,
#   'vid_len': 95},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/59_59.mp4',
#   'split_num': 6,
#   'vid_len': 96},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/2_9.mp4',
#   'split_num': 3,
#   'vid_len': 52},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/40_9.mp4',
#   'split_num': 53,
#   'vid_len': 752},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/51_4.mp4',
#   'split_num': 3,
#   'vid_len': 53},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/69_5.mp4',
#   'split_num': 6,
#   'vid_len': 93},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/61_31.mp4',
#   'split_num': 14,
#   'vid_len': 204},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/113_0.mp4',
#   'split_num': 15,
#   'vid_len': 211},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/33_205.mp4',
#   'split_num': 20,
#   'vid_len': 287},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/87_12.mp4',
#   'split_num': 26,
#   'vid_len': 365},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/52_19.mp4',
#   'split_num': 14,
#   'vid_len': 198},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/3_62.mp4',
#   'split_num': 10,
#   'vid_len': 148},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/18_19.mp4',
#   'split_num': 15,
#   'vid_len': 212},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/31_52.mp4',
#   'split_num': 7,
#   'vid_len': 108},
#  {'path': '/home/kyr/GazeForensicsData/cropped_videos/WDF_crop/fake_test/81_110.mp4',
#   'split_num': 15,
#   'vid_len': 210}]

# %%
with open(rootDir + 'clip_info/WDF_vid_category_dict.json', 'w') as f:
    json.dump(WDF_vid_category_dict, f)
