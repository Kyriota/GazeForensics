# %%
import sys
if '../../' not in sys.path:
    sys.path.append('../../')
from Utils.FileOperation import *
from Config import rootDir

import numpy as np
from PIL import Image, ImageDraw
import time
import cv2
from batch_face import RetinaFace
import math
import json

# %%
aspect_ratio=1.0
def extract(
        detector,
        data_path,
        output_path,
        json_path=None,
        padding=0,
        smooth_level=0,
        batch_size=200
    ):
    '''
    Parameters:
        detector: RetinaFace detector (from batch_face import RetinaFace)
        data_path: path to video file
        output_path: path to output video file
        json_path: path to output json file if this variable is not None
        padding: number of pixels to pad the bounding box
        smooth_level: number of frames to smooth the bounding box
    '''

    troublesome = False

    original_video = cv2.VideoCapture(data_path)
    cnt = 0
    frames = []
    while original_video.isOpened():
        success, frame = original_video.read()
        if not success:
            break
        cnt += 1
        frames.append(frame)
    original_video.release()

    all_faces = []
    for i in range(math.ceil(len(frames)/batch_size)):
        all_faces.extend(detector(frames[i*batch_size:(i+1)*batch_size]))
    
    warned_zero = False
    h_max = 0
    all_boxes = []
    for face_info in all_faces:
        valid_bounding_boxes = []
        for box, landmarks, score in face_info:
            if score < .95:
                continue
            x_min = int(box[0])
            if x_min < 0:
                x_min = 0
            y_min=int(box[1])
            if y_min < 0:
                y_min = 0
            x_max = int(box[2])
            y_max = int(box[3])
            center = (int((x_min + x_max) // 2), int((y_min + y_max) // 2))
            bbox_width = x_max - x_min + 2 * padding
            bbox_height = max(y_max - y_min + 2 * padding, int(bbox_width * aspect_ratio))

            if bbox_height > h_max:
                h_max = bbox_height

            valid_bounding_boxes.append((center, bbox_height, score))

        if len(valid_bounding_boxes) == 0:
            if not warned_zero:
                warned_zero = True
                print('\n * Warning: 404 Faces Not Found at', len(all_boxes))
            all_boxes.append(None)
            continue
        
        elif len(valid_bounding_boxes) > 1:
            all_boxes.append(valid_bounding_boxes)
            continue

        all_boxes.append(valid_bounding_boxes[0][:2])
    
    # Find the mean bounding box center and height by averaging all valid bounding boxes that only have one face
    mean_center = [0, 0]
    mean_bbox_height = 0
    cnt = 0
    for i in range(len(all_boxes)):
        if all_boxes[i] is None or type(all_boxes[i]) is list:
            continue
        mean_center[0] += all_boxes[i][0][0]
        mean_center[1] += all_boxes[i][0][1]
        mean_bbox_height += all_boxes[i][1]
        cnt += 1
    if cnt != 0:
        mean_center[0] /= cnt
        mean_center[1] /= cnt
        mean_bbox_height /= cnt
    else:
        if all_boxes[0] is None:
            print("\n * Warning: 404 Found no face in the entire video!")
            frame = cv2.cvtColor(frames[0], cv2.COLOR_BGR2RGB)
            frame = Image.fromarray(frame)
            frame.show()
            troublesome = True
        else:
            print("\n * Warning: 415 Found", len(all_boxes[0]), "Faces at 0. \n * When you see this message, it's probably because all frames have multiple faces")
            # Show the first frame with all bounding boxes
            frame = cv2.cvtColor(frames[0], cv2.COLOR_BGR2RGB)
            frame = Image.fromarray(frame)
            draw = ImageDraw.Draw(frame)
            for bbox in all_boxes[0]:
                draw.rectangle(get_bounding_box(bbox[0], bbox[1]), outline='red')
            frame.show()
            troublesome = True
            # This is probably because all frames have multiple faces
            # pick the biggest bounding box on the first frame as the mean bounding box
            for bbox in all_boxes[0]:
                if bbox[1] > mean_bbox_height:
                    mean_bbox_height = bbox[1]
                    mean_center = bbox[0]

    warned_multiple = False
    # Find the most appropriate bounding box for frames that have multiple faces by calculating IoU with mean bounding box
    for i in range(len(all_boxes)):
        if all_boxes[i] is None or type(all_boxes[i]) is tuple:
            continue
        best_bbox = None
        best_iou = 0
        for bbox in all_boxes[i]:
            iou = compute_iou(bbox, (mean_center, mean_bbox_height))
            if iou > best_iou:
                best_iou = iou
                best_bbox = bbox
        if best_bbox is None:
            # If no bounding box has IoU > 0, drop this frame
            if not warned_multiple:
                warned_multiple = True
                print('\n * Warning: 409 Found', len(all_boxes[i]), 'Faces at', i)
                troublesome = True
            # Draw all bounding boxes in red and mean bounding box in green on the frame and use PIL.Image to show it
            frame = cv2.cvtColor(frames[i], cv2.COLOR_BGR2RGB)
            frame = Image.fromarray(frame)
            draw = ImageDraw.Draw(frame)
            for bbox in all_boxes[i]:
                draw.rectangle(get_bounding_box(bbox[0], bbox[1]), outline='red')
            draw.rectangle(get_bounding_box(mean_center, mean_bbox_height), outline='green')
            frame.show()
            all_boxes[i] = None
            continue
        all_boxes[i] = best_bbox

    output_size = (int(h_max // aspect_ratio), h_max)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    if troublesome:
        output_path_elements = output_path.split('/')
        last_len = len(output_path_elements[-1])
        output_path_elements[-1] = 'troublesome/' + output_path_elements[-1]
        output_path = '/'.join(output_path_elements)
        mkdir(output_path[:-last_len])
    out = cv2.VideoWriter(output_path, fourcc, 30.0, output_size)
    calculated_boxes = []
    for i in range(len(frames)):
        if all_boxes[i] is None:
            calculated_boxes.append(None)
            continue
        frame = frames[i]
        id_0 = max(0, i - smooth_level // 2)
        id_1 = min(len(all_boxes), i + 1 + math.ceil(smooth_level / 2))
        center, bbox_height = smooth_frames(all_boxes[id_0:id_1], i - id_0)
        bbox = get_bounding_box(center, bbox_height)
        calculated_boxes.append(bbox)
        frame = Image.fromarray(frame).crop(bbox).resize(output_size)
        out.write(np.array(frame))
    out.release()

    assert len(calculated_boxes) == len(frames)

    # Save calculated_boxes as json file
    if json_path is not None:
        if troublesome:
            json_path_elements = json_path.split('/')
            last_len = len(json_path_elements[-1])
            json_path_elements[-1] = 'troublesome/' + json_path_elements[-1]
            json_path = '/'.join(json_path_elements)
            mkdir(json_path[:-last_len])
        with open(json_path, 'w') as f:
            json.dump(calculated_boxes, f)


def smooth_frames(bounding_boxes, target_index, iou_threshold=0.5):
    '''
    Smooth bounding boxes using linear interpolation
    Parameters:
        bounding_boxes: List of bounding boxes, length of list means smooth level
        target_index: Targeted frame index
        iou_threshold: IoU threshold to filter out bounding boxes
    Return:
        One smoothed bounding box
    Bounding box structure:
        (center, bbox_height)
    '''

    # Make sure target_index is not None
    if bounding_boxes[target_index] is None:
        return None

    # Filter out bounding boxes equal to None
    invalid_cnt_before_target = 0
    for i in range(target_index):
        if bounding_boxes[i] is None:
            invalid_cnt_before_target += 1
    target_index -= invalid_cnt_before_target
    bounding_boxes = [bbox for bbox in bounding_boxes if bbox is not None]
    
    # Linear interpolation
    # If bounding boxes have no intersection with targeted frame, don't count it
    # Intersection is calculated by IoU
    mean_center = [0, 0]
    mean_bbox_height = 0
    cnt = 0
    for i in range(len(bounding_boxes)):
        bbox = bounding_boxes[i]
        if bbox is None:
            continue
        iou = compute_iou(bbox, bounding_boxes[target_index])
        if iou < iou_threshold:
            continue
        mean_center[0] += bbox[0][0]
        mean_center[1] += bbox[0][1]
        mean_bbox_height += bbox[1]
        cnt += 1
    mean_center[0] /= cnt
    mean_center[1] /= cnt
    mean_bbox_height /= cnt
    return (mean_center, mean_bbox_height)


def get_bounding_box(center, bbox_height):
    '''
    Get bounding box from center and bbox_height
    '''
    bbox_width = bbox_height // aspect_ratio
    x_min = int(center[0] - bbox_width // 2)
    y_min = int(center[1] - bbox_height // 2)
    x_max = int(center[0] + bbox_width // 2)
    y_max = int(center[1] + bbox_height // 2)
    return (x_min, y_min, x_max, y_max)

def compute_iou(bbox0, bbox1):
    '''
    Compute IoU of two bounding boxes
    '''
    x_min0, y_min0, x_max0, y_max0 = get_bounding_box(bbox0[0], bbox0[1])
    x_min1, y_min1, x_max1, y_max1 = get_bounding_box(bbox1[0], bbox1[1])
    x_min = max(x_min0, x_min1)
    y_min = max(y_min0, y_min1)
    x_max = min(x_max0, x_max1)
    y_max = min(y_max0, y_max1)
    intersection = max(0, x_max - x_min) * max(0, y_max - y_min)
    union = (x_max0 - x_min0) * (y_max0 - y_min0) + (x_max1 - x_min1) * (y_max1 - y_min1) - intersection
    return intersection / union

# %%
detector = RetinaFace(gpu_id=0)
dataDirs = [
    rootDir + 'cropped_videos/FF++_crop_basic/c23/real/',
    rootDir + 'cropped_videos/FF++_crop_basic/c23/fake/Deepfakes/',
    rootDir + 'cropped_videos/FF++_crop_basic/c23/fake/Face2Face/',
    rootDir + 'cropped_videos/FF++_crop_basic/c23/fake/FaceSwap/',
    rootDir + 'cropped_videos/FF++_crop_basic/c23/fake/NeuralTextures/',
]
for dataDir in dataDirs:
    saveDir = dataDir.replace('_basic', '')
    jsonDir = dataDir.replace('_basic/c23', '/json')
    vidDirs = ls(dataDir)
    savedList = ls(saveDir)
    for vidDir in vidDirs:
        if vidDir in savedList:
            saved = cv2.VideoCapture(saveDir + vidDir)
            saved_frame_count = int(saved.get(cv2.CAP_PROP_FRAME_COUNT))
            saved.release()
            original = cv2.VideoCapture(dataDir + vidDir)
            original_frame_count = int(original.get(cv2.CAP_PROP_FRAME_COUNT))
            original.release()
            if saved_frame_count == original_frame_count:
                continue
        print(time.ctime(time.time()), ':', dataDir + vidDir)
        try:
            extract(
                detector,
                dataDir + vidDir,
                saveDir + vidDir,
                json_path=jsonDir+vidDir[:-4]+'.json',
                padding=18,
                smooth_level=5
            )
        except:
            print("\n>>>>>>>>>> ERROR OCCURED <<<<<<<<<<")
# Out:
# Thu Mar 14 16:39:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c23/real/340.mp4

# %%
def extract_with_json(
        detector,
        data_path,
        output_path,
        json_path
    ):
    '''
    Parameters:
        data_path: path to video file
        output_path: path to output video file
        json_path: path to the json file of bounding box data
    '''
    original_video = cv2.VideoCapture(data_path)
    frames = []
    while original_video.isOpened():
        success, frame = original_video.read()
        if not success:
            break
        frames.append(frame)
    original_video.release()

    with open(json_path, 'r') as f:
        calculated_boxes = json.load(f) # Data structure: [[x_min, y_min, x_max, y_max], ...]
    
    if len(frames) < len(calculated_boxes):
        # Delete all None in calculated_boxes
        calculated_boxes = [box for box in calculated_boxes if box is not None]

    if len(frames) != len(calculated_boxes):
        print('\n>>> Error: The number of frames and the number of bounding boxes do not match.', len(frames), len(calculated_boxes))
        extract(
            detector,
            data_path,
            output_path,
            json_path=None,
            padding=18,
            smooth_level=5,
            batch_size=400
        )
    
    # Find the max height of the bounding boxes
    max_height = 0
    for bbox in calculated_boxes:
        if bbox is None:
            continue
        height = bbox[3] - bbox[1]
        if height > max_height:
            max_height = height

    # Save the cropped frames into .mp4
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    output_size = (int(max_height / aspect_ratio), max_height)
    out = cv2.VideoWriter(output_path, fourcc, 30, output_size)
    for frame, bbox in zip(frames, calculated_boxes):
        if bbox is None:
            continue
        frame = Image.fromarray(frame).crop(bbox).resize(output_size)
        out.write(np.array(frame))
    out.release()

# %% [markdown]
# Before next step, move all files in 'troublesome' folder to its parent directory.

# %%
detector = RetinaFace(gpu_id=0)
dataDirs = [
    rootDir + 'cropped_videos/FF++_crop_basic/c40/real/',
    rootDir + 'cropped_videos/FF++_crop_basic/c40/fake/Deepfakes/',
    rootDir + 'cropped_videos/FF++_crop_basic/c40/fake/Face2Face/',
    rootDir + 'cropped_videos/FF++_crop_basic/c40/fake/FaceSwap/',
    rootDir + 'cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/',
]
for dataDir in dataDirs:
    saveDir = dataDir.replace('_basic', '')
    vidDirs = ls(dataDir)
    savedList = ls(saveDir)
    jsonsDir = saveDir.replace('c40', 'json')
    for vidDir in vidDirs:
        if vidDir in savedList:
            saved = cv2.VideoCapture(saveDir + vidDir)
            saved_frame_count = int(saved.get(cv2.CAP_PROP_FRAME_COUNT))
            saved.release()
            original = cv2.VideoCapture(dataDir + vidDir)
            original_frame_count = int(original.get(cv2.CAP_PROP_FRAME_COUNT))
            original.release()
            if saved_frame_count == original_frame_count:
                continue
        jsonDir = vidDir.replace('mp4', 'json')
        print(time.ctime(time.time()), ':', dataDir + vidDir)
        try:
            extract_with_json(
                detector,
                dataDir + vidDir,
                saveDir + vidDir,
                jsonsDir + jsonDir
            )
        except:
            print("\n>>>>>>>>>> ERROR OCCURED <<<<<<<<<<")
# Out:
# Thu Mar 14 16:40:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/006.mp4
# Thu Mar 14 16:40:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/007.mp4
# Thu Mar 14 16:40:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/008.mp4
# Thu Mar 14 16:40:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/009.mp4
# Thu Mar 14 16:40:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/010.mp4
# Thu Mar 14 16:40:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/011.mp4
# Thu Mar 14 16:40:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/012.mp4
# Thu Mar 14 16:40:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/013.mp4
# Thu Mar 14 16:40:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/014.mp4
# Thu Mar 14 16:40:17 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/015.mp4
# Thu Mar 14 16:40:17 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/016.mp4
# Thu Mar 14 16:40:17 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/017.mp4
# Thu Mar 14 16:40:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/018.mp4
# Thu Mar 14 16:40:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/019.mp4
# Thu Mar 14 16:40:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/020.mp4
# Thu Mar 14 16:40:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/021.mp4
# Thu Mar 14 16:40:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/022.mp4
# Thu Mar 14 16:40:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/023.mp4
# Thu Mar 14 16:40:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/024.mp4
# Thu Mar 14 16:40:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/025.mp4
# Thu Mar 14 16:40:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/026.mp4
# Thu Mar 14 16:40:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/027.mp4
# Thu Mar 14 16:40:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/028.mp4
# Thu Mar 14 16:40:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/029.mp4
# Thu Mar 14 16:40:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/030.mp4
# Thu Mar 14 16:40:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/031.mp4
# Thu Mar 14 16:40:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/032.mp4
# Thu Mar 14 16:40:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/033.mp4
# Thu Mar 14 16:40:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/034.mp4
# Thu Mar 14 16:40:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/035.mp4
# Thu Mar 14 16:40:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/036.mp4
# Thu Mar 14 16:40:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/037.mp4
# Thu Mar 14 16:40:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/038.mp4
# Thu Mar 14 16:40:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/039.mp4
# Thu Mar 14 16:40:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/040.mp4
# Thu Mar 14 16:40:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/041.mp4
# Thu Mar 14 16:40:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/042.mp4
# Thu Mar 14 16:40:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/043.mp4
# Thu Mar 14 16:40:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/044.mp4
# Thu Mar 14 16:40:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/045.mp4
# Thu Mar 14 16:40:34 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/046.mp4
# Thu Mar 14 16:40:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/047.mp4
# Thu Mar 14 16:40:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/048.mp4
# Thu Mar 14 16:40:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/049.mp4
# Thu Mar 14 16:40:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/050.mp4
# Thu Mar 14 16:40:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/051.mp4
# Thu Mar 14 16:40:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/052.mp4
# Thu Mar 14 16:40:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/053.mp4
# Thu Mar 14 16:40:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/054.mp4
# Thu Mar 14 16:40:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/055.mp4
# Thu Mar 14 16:40:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/056.mp4
# Thu Mar 14 16:40:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/057.mp4
# Thu Mar 14 16:40:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/058.mp4
# Thu Mar 14 16:40:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/059.mp4
# Thu Mar 14 16:40:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/060.mp4
# Thu Mar 14 16:40:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/061.mp4
# Thu Mar 14 16:40:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/062.mp4
# Thu Mar 14 16:40:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/063.mp4
# Thu Mar 14 16:40:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/064.mp4
# Thu Mar 14 16:40:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/065.mp4
# Thu Mar 14 16:40:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/066.mp4
# Thu Mar 14 16:40:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/067.mp4
# Thu Mar 14 16:40:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/068.mp4
# Thu Mar 14 16:40:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/069.mp4
# Thu Mar 14 16:40:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/070.mp4
# Thu Mar 14 16:40:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/071.mp4
# Thu Mar 14 16:40:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/072.mp4
# Thu Mar 14 16:40:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/073.mp4
# Thu Mar 14 16:40:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/074.mp4
# Thu Mar 14 16:40:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/075.mp4
# Thu Mar 14 16:40:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/076.mp4
# Thu Mar 14 16:40:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/077.mp4
# Thu Mar 14 16:40:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/078.mp4
# Thu Mar 14 16:40:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/079.mp4
# Thu Mar 14 16:40:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/080.mp4
# Thu Mar 14 16:40:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/081.mp4
# Thu Mar 14 16:40:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/082.mp4
# Thu Mar 14 16:40:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/083.mp4
# Thu Mar 14 16:41:00 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/084.mp4
# Thu Mar 14 16:41:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/085.mp4
# Thu Mar 14 16:41:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/086.mp4
# Thu Mar 14 16:41:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/087.mp4
# Thu Mar 14 16:41:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/088.mp4
# Thu Mar 14 16:41:04 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/089.mp4
# Thu Mar 14 16:41:05 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/090.mp4
# Thu Mar 14 16:41:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/091.mp4
# Thu Mar 14 16:41:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/092.mp4
# Thu Mar 14 16:41:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/093.mp4
# Thu Mar 14 16:41:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/094.mp4
# Thu Mar 14 16:41:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/095.mp4
# Thu Mar 14 16:41:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/096.mp4
# Thu Mar 14 16:41:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/097.mp4
# Thu Mar 14 16:41:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/098.mp4
# Thu Mar 14 16:41:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/099.mp4
# Thu Mar 14 16:41:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/100.mp4
# Thu Mar 14 16:41:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/101.mp4
# Thu Mar 14 16:41:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/102.mp4
# Thu Mar 14 16:41:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/103.mp4
# Thu Mar 14 16:41:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/104.mp4
# Thu Mar 14 16:41:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/105.mp4
# Thu Mar 14 16:41:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/106.mp4
# Thu Mar 14 16:41:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/107.mp4
# Thu Mar 14 16:41:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/108.mp4
# Thu Mar 14 16:41:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/109.mp4
# Thu Mar 14 16:41:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/110.mp4
# Thu Mar 14 16:41:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/111.mp4
# Thu Mar 14 16:41:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/112.mp4
# Thu Mar 14 16:41:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/113.mp4
# Thu Mar 14 16:41:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/114.mp4
# Thu Mar 14 16:41:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/115.mp4
# Thu Mar 14 16:41:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/116.mp4
# Thu Mar 14 16:41:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/117.mp4
# Thu Mar 14 16:41:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/118.mp4
# Thu Mar 14 16:41:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/119.mp4
# Thu Mar 14 16:41:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/120.mp4
# Thu Mar 14 16:41:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/121.mp4
# Thu Mar 14 16:41:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/122.mp4
# Thu Mar 14 16:41:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/123.mp4
# Thu Mar 14 16:41:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/124.mp4
# Thu Mar 14 16:41:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/125.mp4
# Thu Mar 14 16:41:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/126.mp4
# Thu Mar 14 16:41:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/127.mp4
# Thu Mar 14 16:41:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/128.mp4
# Thu Mar 14 16:41:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/129.mp4
# Thu Mar 14 16:41:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/130.mp4
# Thu Mar 14 16:41:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/131.mp4
# Thu Mar 14 16:41:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/132.mp4
# Thu Mar 14 16:41:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/133.mp4
# Thu Mar 14 16:41:34 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/134.mp4
# Thu Mar 14 16:41:34 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/135.mp4
# Thu Mar 14 16:41:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/136.mp4
# Thu Mar 14 16:41:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/137.mp4
# Thu Mar 14 16:41:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/138.mp4
# Thu Mar 14 16:41:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/139.mp4
# Thu Mar 14 16:41:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/140.mp4
# Thu Mar 14 16:41:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/141.mp4
# Thu Mar 14 16:41:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/142.mp4
# Thu Mar 14 16:41:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/143.mp4
# Thu Mar 14 16:41:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/144.mp4
# Thu Mar 14 16:41:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/145.mp4
# Thu Mar 14 16:41:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/146.mp4
# Thu Mar 14 16:41:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/147.mp4
# Thu Mar 14 16:41:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/148.mp4
# Thu Mar 14 16:41:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/149.mp4
# Thu Mar 14 16:41:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/150.mp4
# Thu Mar 14 16:41:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/151.mp4
# Thu Mar 14 16:41:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/152.mp4
# Thu Mar 14 16:41:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/153.mp4
# Thu Mar 14 16:41:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/154.mp4
# Thu Mar 14 16:41:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/155.mp4
# Thu Mar 14 16:41:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/156.mp4
# Thu Mar 14 16:41:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/157.mp4
# Thu Mar 14 16:41:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/158.mp4
# Thu Mar 14 16:41:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/159.mp4
# Thu Mar 14 16:41:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/160.mp4
# Thu Mar 14 16:41:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/161.mp4
# Thu Mar 14 16:41:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/162.mp4
# Thu Mar 14 16:41:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/163.mp4
# Thu Mar 14 16:41:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/164.mp4
# Thu Mar 14 16:41:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/165.mp4
# Thu Mar 14 16:41:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/166.mp4
# Thu Mar 14 16:41:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/167.mp4
# Thu Mar 14 16:41:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/168.mp4
# Thu Mar 14 16:41:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/169.mp4
# Thu Mar 14 16:41:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/170.mp4
# Thu Mar 14 16:41:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/171.mp4
# Thu Mar 14 16:41:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/172.mp4
# Thu Mar 14 16:41:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/173.mp4
# Thu Mar 14 16:42:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/174.mp4
# Thu Mar 14 16:42:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/175.mp4
# Thu Mar 14 16:42:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/176.mp4
# Thu Mar 14 16:42:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/177.mp4
# Thu Mar 14 16:42:04 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/178.mp4
# Thu Mar 14 16:42:04 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/179.mp4
# Thu Mar 14 16:42:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/180.mp4
# Thu Mar 14 16:42:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/181.mp4
# Thu Mar 14 16:42:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/182.mp4
# Thu Mar 14 16:42:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/183.mp4
# Thu Mar 14 16:42:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/184.mp4
# Thu Mar 14 16:42:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/185.mp4
# Thu Mar 14 16:42:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/186.mp4
# Thu Mar 14 16:42:11 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/187.mp4
# Thu Mar 14 16:42:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/188.mp4
# Thu Mar 14 16:42:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/189.mp4
# Thu Mar 14 16:42:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/190.mp4
# Thu Mar 14 16:42:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/191.mp4
# Thu Mar 14 16:42:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/192.mp4
# Thu Mar 14 16:42:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/193.mp4
# Thu Mar 14 16:42:17 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/194.mp4
# Thu Mar 14 16:42:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/195.mp4
# Thu Mar 14 16:42:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/196.mp4
# Thu Mar 14 16:42:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/197.mp4
# Thu Mar 14 16:42:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/198.mp4
# Thu Mar 14 16:42:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/199.mp4
# Thu Mar 14 16:42:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/200.mp4
# Thu Mar 14 16:42:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/201.mp4
# Thu Mar 14 16:42:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/202.mp4
# Thu Mar 14 16:42:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/203.mp4
# Thu Mar 14 16:42:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/204.mp4
# Thu Mar 14 16:42:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/205.mp4
# Thu Mar 14 16:42:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/206.mp4
# Thu Mar 14 16:42:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/207.mp4
# Thu Mar 14 16:42:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/208.mp4
# Thu Mar 14 16:42:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/209.mp4
# Thu Mar 14 16:42:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/210.mp4
# Thu Mar 14 16:42:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/211.mp4
# Thu Mar 14 16:42:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/212.mp4
# Thu Mar 14 16:42:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/213.mp4
# Thu Mar 14 16:42:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/214.mp4
# Thu Mar 14 16:42:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/215.mp4
# Thu Mar 14 16:42:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/216.mp4
# Thu Mar 14 16:42:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/217.mp4
# Thu Mar 14 16:42:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/218.mp4
# Thu Mar 14 16:42:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/219.mp4
# Thu Mar 14 16:42:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/220.mp4
# Thu Mar 14 16:42:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/221.mp4
# Thu Mar 14 16:42:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/222.mp4
# Thu Mar 14 16:42:34 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/223.mp4
# Thu Mar 14 16:42:34 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/224.mp4
# Thu Mar 14 16:42:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/225.mp4
# Thu Mar 14 16:42:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/226.mp4
# Thu Mar 14 16:42:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/227.mp4
# Thu Mar 14 16:42:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/228.mp4
# Thu Mar 14 16:42:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/229.mp4
# Thu Mar 14 16:42:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/230.mp4
# Thu Mar 14 16:42:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/231.mp4
# Thu Mar 14 16:42:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/232.mp4
# Thu Mar 14 16:42:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/233.mp4
# Thu Mar 14 16:42:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/234.mp4
# Thu Mar 14 16:42:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/235.mp4
# Thu Mar 14 16:42:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/236.mp4
# Thu Mar 14 16:42:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/237.mp4
# Thu Mar 14 16:42:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/238.mp4
# Thu Mar 14 16:42:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/239.mp4
# Thu Mar 14 16:42:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/240.mp4
# Thu Mar 14 16:42:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/241.mp4
# Thu Mar 14 16:42:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/242.mp4
# Thu Mar 14 16:42:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/243.mp4
# Thu Mar 14 16:42:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/244.mp4
# Thu Mar 14 16:42:46 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/245.mp4
# Thu Mar 14 16:42:46 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/246.mp4
# Thu Mar 14 16:42:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/247.mp4
# Thu Mar 14 16:42:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/248.mp4
# Thu Mar 14 16:42:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/249.mp4
# Thu Mar 14 16:42:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/250.mp4
# Thu Mar 14 16:42:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/251.mp4
# Thu Mar 14 16:42:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/252.mp4
# Thu Mar 14 16:42:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/253.mp4
# Thu Mar 14 16:42:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/254.mp4
# Thu Mar 14 16:42:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/255.mp4
# Thu Mar 14 16:42:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/256.mp4
# Thu Mar 14 16:42:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/257.mp4
# Thu Mar 14 16:42:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/258.mp4
# Thu Mar 14 16:42:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/259.mp4
# Thu Mar 14 16:42:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/260.mp4
# Thu Mar 14 16:42:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/261.mp4
# Thu Mar 14 16:42:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/262.mp4
# Thu Mar 14 16:42:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/263.mp4
# Thu Mar 14 16:42:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/264.mp4
# Thu Mar 14 16:42:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/265.mp4
# Thu Mar 14 16:42:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/266.mp4
# Thu Mar 14 16:42:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/267.mp4
# Thu Mar 14 16:43:00 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/268.mp4
# Thu Mar 14 16:43:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/269.mp4
# Thu Mar 14 16:43:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/270.mp4
# Thu Mar 14 16:43:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/271.mp4
# Thu Mar 14 16:43:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/272.mp4
# Thu Mar 14 16:43:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/273.mp4
# Thu Mar 14 16:43:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/274.mp4
# Thu Mar 14 16:43:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/275.mp4
# Thu Mar 14 16:43:04 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/276.mp4
# Thu Mar 14 16:43:05 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/277.mp4
# Thu Mar 14 16:43:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/278.mp4
# Thu Mar 14 16:43:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/279.mp4
# Thu Mar 14 16:43:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/280.mp4
# Thu Mar 14 16:43:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/281.mp4
# Thu Mar 14 16:43:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/282.mp4
# Thu Mar 14 16:43:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/283.mp4
# Thu Mar 14 16:43:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/284.mp4
# Thu Mar 14 16:43:11 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/285.mp4
# Thu Mar 14 16:43:11 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/286.mp4
# Thu Mar 14 16:43:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/287.mp4
# Thu Mar 14 16:43:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/288.mp4
# Thu Mar 14 16:43:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/289.mp4
# Thu Mar 14 16:43:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/290.mp4
# Thu Mar 14 16:43:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/291.mp4
# Thu Mar 14 16:43:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/292.mp4
# Thu Mar 14 16:43:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/293.mp4
# Thu Mar 14 16:43:17 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/294.mp4
# Thu Mar 14 16:43:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/295.mp4
# Thu Mar 14 16:43:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/296.mp4
# Thu Mar 14 16:43:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/297.mp4
# Thu Mar 14 16:43:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/298.mp4
# Thu Mar 14 16:43:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/299.mp4
# Thu Mar 14 16:43:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/300.mp4
# Thu Mar 14 16:43:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/301.mp4
# Thu Mar 14 16:43:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/302.mp4
# Thu Mar 14 16:43:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/303.mp4
# Thu Mar 14 16:43:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/304.mp4
# Thu Mar 14 16:43:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/305.mp4
# Thu Mar 14 16:43:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/306.mp4
# Thu Mar 14 16:43:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/307.mp4
# Thu Mar 14 16:43:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/308.mp4
# Thu Mar 14 16:43:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/309.mp4
# Thu Mar 14 16:43:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/310.mp4
# Thu Mar 14 16:43:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/311.mp4
# Thu Mar 14 16:43:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/312.mp4
# Thu Mar 14 16:43:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/313.mp4
# Thu Mar 14 16:43:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/314.mp4
# Thu Mar 14 16:43:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/315.mp4
# Thu Mar 14 16:43:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/316.mp4
# Thu Mar 14 16:43:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/317.mp4
# Thu Mar 14 16:43:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/318.mp4
# Thu Mar 14 16:43:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/319.mp4
# Thu Mar 14 16:43:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/320.mp4
# Thu Mar 14 16:43:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/321.mp4
# Thu Mar 14 16:43:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/322.mp4
# Thu Mar 14 16:43:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/323.mp4
# Thu Mar 14 16:43:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/324.mp4
# Thu Mar 14 16:43:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/325.mp4
# Thu Mar 14 16:43:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/326.mp4
# Thu Mar 14 16:43:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/327.mp4
# Thu Mar 14 16:43:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/328.mp4
# Thu Mar 14 16:43:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/329.mp4
# Thu Mar 14 16:43:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/330.mp4
# Thu Mar 14 16:43:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/331.mp4
# Thu Mar 14 16:43:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/332.mp4
# Thu Mar 14 16:43:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/333.mp4
# Thu Mar 14 16:43:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/334.mp4
# Thu Mar 14 16:43:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/335.mp4
# Thu Mar 14 16:43:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/336.mp4
# Thu Mar 14 16:43:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/337.mp4
# Thu Mar 14 16:43:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/338.mp4
# Thu Mar 14 16:43:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/339.mp4
# Thu Mar 14 16:43:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/340.mp4
# Thu Mar 14 16:43:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/341.mp4
# Thu Mar 14 16:43:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/342.mp4
# Thu Mar 14 16:43:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/343.mp4
# Thu Mar 14 16:43:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/344.mp4
# Thu Mar 14 16:43:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/345.mp4
# Thu Mar 14 16:43:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/346.mp4
# Thu Mar 14 16:43:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/347.mp4
# Thu Mar 14 16:43:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/348.mp4
# Thu Mar 14 16:43:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/349.mp4
# Thu Mar 14 16:43:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/350.mp4
# Thu Mar 14 16:43:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/351.mp4
# Thu Mar 14 16:43:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/352.mp4
# Thu Mar 14 16:43:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/353.mp4
# Thu Mar 14 16:43:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/354.mp4
# Thu Mar 14 16:43:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/355.mp4
# Thu Mar 14 16:43:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/356.mp4
# Thu Mar 14 16:43:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/357.mp4
# Thu Mar 14 16:43:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/358.mp4
# Thu Mar 14 16:43:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/359.mp4
# Thu Mar 14 16:43:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/360.mp4
# Thu Mar 14 16:43:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/361.mp4
# Thu Mar 14 16:44:00 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/362.mp4
# Thu Mar 14 16:44:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/363.mp4
# Thu Mar 14 16:44:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/364.mp4
# Thu Mar 14 16:44:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/365.mp4
# Thu Mar 14 16:44:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/366.mp4
# Thu Mar 14 16:44:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/367.mp4
# Thu Mar 14 16:44:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/368.mp4
# Thu Mar 14 16:44:05 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/369.mp4
# Thu Mar 14 16:44:05 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/370.mp4
# Thu Mar 14 16:44:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/371.mp4
# Thu Mar 14 16:44:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/372.mp4
# Thu Mar 14 16:44:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/373.mp4
# Thu Mar 14 16:44:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/374.mp4
# Thu Mar 14 16:44:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/375.mp4
# Thu Mar 14 16:44:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/376.mp4
# Thu Mar 14 16:44:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/377.mp4
# Thu Mar 14 16:44:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/378.mp4
# Thu Mar 14 16:44:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/379.mp4
# Thu Mar 14 16:44:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/380.mp4
# Thu Mar 14 16:44:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/381.mp4
# Thu Mar 14 16:44:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/382.mp4
# Thu Mar 14 16:44:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/383.mp4
# Thu Mar 14 16:44:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/384.mp4
# Thu Mar 14 16:44:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/385.mp4
# Thu Mar 14 16:44:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/386.mp4
# Thu Mar 14 16:44:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/387.mp4
# Thu Mar 14 16:44:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/388.mp4
# Thu Mar 14 16:44:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/389.mp4
# Thu Mar 14 16:44:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/390.mp4
# Thu Mar 14 16:44:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/391.mp4
# Thu Mar 14 16:44:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/392.mp4
# Thu Mar 14 16:44:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/393.mp4
# Thu Mar 14 16:44:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/394.mp4
# Thu Mar 14 16:44:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/395.mp4
# Thu Mar 14 16:44:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/396.mp4
# Thu Mar 14 16:44:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/397.mp4
# Thu Mar 14 16:44:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/398.mp4
# Thu Mar 14 16:44:29 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/399.mp4
# Thu Mar 14 16:44:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/400.mp4
# Thu Mar 14 16:44:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/401.mp4
# Thu Mar 14 16:44:34 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/402.mp4
# Thu Mar 14 16:44:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/403.mp4
# Thu Mar 14 16:44:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/404.mp4
# Thu Mar 14 16:44:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/405.mp4
# Thu Mar 14 16:44:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/406.mp4
# Thu Mar 14 16:44:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/407.mp4
# Thu Mar 14 16:44:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/408.mp4
# Thu Mar 14 16:44:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/409.mp4
# Thu Mar 14 16:44:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/410.mp4
# Thu Mar 14 16:44:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/411.mp4
# Thu Mar 14 16:44:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/412.mp4
# Thu Mar 14 16:44:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/413.mp4
# Thu Mar 14 16:44:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/414.mp4
# Thu Mar 14 16:44:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/415.mp4
# Thu Mar 14 16:44:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/416.mp4
# Thu Mar 14 16:44:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/417.mp4
# Thu Mar 14 16:44:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/418.mp4
# Thu Mar 14 16:44:46 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/419.mp4
# Thu Mar 14 16:44:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/420.mp4
# Thu Mar 14 16:44:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/421.mp4
# Thu Mar 14 16:44:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/422.mp4
# Thu Mar 14 16:44:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/423.mp4
# Thu Mar 14 16:44:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/424.mp4
# Thu Mar 14 16:44:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/425.mp4
# Thu Mar 14 16:44:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/426.mp4
# Thu Mar 14 16:44:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/427.mp4
# Thu Mar 14 16:44:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/428.mp4
# Thu Mar 14 16:44:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/429.mp4
# Thu Mar 14 16:44:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/430.mp4
# Thu Mar 14 16:44:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/431.mp4
# Thu Mar 14 16:44:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/432.mp4
# Thu Mar 14 16:44:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/433.mp4
# Thu Mar 14 16:44:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/434.mp4
# Thu Mar 14 16:44:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/435.mp4
# Thu Mar 14 16:44:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/436.mp4
# Thu Mar 14 16:44:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/437.mp4
# Thu Mar 14 16:44:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/438.mp4
# Thu Mar 14 16:44:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/439.mp4
# Thu Mar 14 16:45:00 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/440.mp4
# Thu Mar 14 16:45:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/441.mp4
# Thu Mar 14 16:45:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/442.mp4
# Thu Mar 14 16:45:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/443.mp4
# Thu Mar 14 16:45:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/444.mp4
# Thu Mar 14 16:45:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/445.mp4
# Thu Mar 14 16:45:05 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/446.mp4
# Thu Mar 14 16:45:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/447.mp4
# Thu Mar 14 16:45:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/448.mp4
# Thu Mar 14 16:45:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/449.mp4
# Thu Mar 14 16:45:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/450.mp4
# Thu Mar 14 16:45:11 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/451.mp4
# Thu Mar 14 16:45:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/452.mp4
# Thu Mar 14 16:45:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/453.mp4
# Thu Mar 14 16:45:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/454.mp4
# Thu Mar 14 16:45:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/455.mp4
# Thu Mar 14 16:45:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/456.mp4
# Thu Mar 14 16:45:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/457.mp4
# Thu Mar 14 16:45:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/458.mp4
# Thu Mar 14 16:45:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/459.mp4
# Thu Mar 14 16:45:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/460.mp4
# Thu Mar 14 16:45:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/461.mp4
# Thu Mar 14 16:45:20 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/462.mp4
# Thu Mar 14 16:45:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/463.mp4
# Thu Mar 14 16:45:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/464.mp4
# Thu Mar 14 16:45:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/465.mp4
# Thu Mar 14 16:45:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/466.mp4
# Thu Mar 14 16:45:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/467.mp4
# Thu Mar 14 16:45:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/468.mp4
# Thu Mar 14 16:45:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/469.mp4
# Thu Mar 14 16:45:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/470.mp4
# Thu Mar 14 16:45:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/real/471.mp4
# ...
# Thu Mar 14 17:33:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/869_780.mp4
# Thu Mar 14 17:33:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/870_001.mp4
# Thu Mar 14 17:33:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/871_814.mp4
# Thu Mar 14 17:33:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/872_873.mp4
# Thu Mar 14 17:33:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/873_872.mp4
# Thu Mar 14 17:33:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/874_291.mp4
# Thu Mar 14 17:33:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/875_979.mp4
# Thu Mar 14 17:33:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/876_891.mp4
# Thu Mar 14 17:33:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/877_886.mp4
# Thu Mar 14 17:33:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/878_866.mp4
# Thu Mar 14 17:33:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/879_963.mp4
# Thu Mar 14 17:33:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/880_135.mp4
# Thu Mar 14 17:33:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/881_856.mp4
# Thu Mar 14 17:33:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/882_952.mp4
# Thu Mar 14 17:33:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/883_013.mp4
# Thu Mar 14 17:33:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/884_968.mp4
# Thu Mar 14 17:33:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/885_802.mp4
# Thu Mar 14 17:33:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/886_877.mp4
# Thu Mar 14 17:33:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/887_275.mp4
# Thu Mar 14 17:33:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/888_937.mp4
# Thu Mar 14 17:33:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/889_045.mp4
# Thu Mar 14 17:33:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/890_837.mp4
# Thu Mar 14 17:33:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/891_876.mp4
# Thu Mar 14 17:33:55 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/892_112.mp4
# Thu Mar 14 17:33:56 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/893_913.mp4
# Thu Mar 14 17:33:57 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/894_848.mp4
# Thu Mar 14 17:33:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/895_915.mp4
# Thu Mar 14 17:33:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/896_128.mp4
# Thu Mar 14 17:33:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/897_969.mp4
# Thu Mar 14 17:33:58 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/898_922.mp4
# Thu Mar 14 17:33:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/899_914.mp4
# Thu Mar 14 17:33:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/900_926.mp4
# Thu Mar 14 17:33:59 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/901_902.mp4
# Thu Mar 14 17:34:00 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/902_901.mp4
# Thu Mar 14 17:34:00 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/903_792.mp4
# Thu Mar 14 17:34:01 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/904_046.mp4
# Thu Mar 14 17:34:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/905_860.mp4
# Thu Mar 14 17:34:02 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/906_847.mp4
# Thu Mar 14 17:34:03 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/907_795.mp4
# Thu Mar 14 17:34:04 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/908_207.mp4
# Thu Mar 14 17:34:05 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/909_857.mp4
# Thu Mar 14 17:34:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/910_911.mp4
# Thu Mar 14 17:34:06 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/911_910.mp4
# Thu Mar 14 17:34:07 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/912_927.mp4
# Thu Mar 14 17:34:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/913_893.mp4
# Thu Mar 14 17:34:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/914_899.mp4
# Thu Mar 14 17:34:08 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/915_895.mp4
# Thu Mar 14 17:34:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/916_783.mp4
# Thu Mar 14 17:34:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/917_924.mp4
# Thu Mar 14 17:34:09 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/918_934.mp4
# Thu Mar 14 17:34:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/919_015.mp4
# Thu Mar 14 17:34:10 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/920_811.mp4
# Thu Mar 14 17:34:11 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/921_569.mp4
# Thu Mar 14 17:34:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/922_898.mp4
# Thu Mar 14 17:34:12 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/923_023.mp4
# Thu Mar 14 17:34:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/924_917.mp4
# Thu Mar 14 17:34:13 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/925_933.mp4
# Thu Mar 14 17:34:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/926_900.mp4
# Thu Mar 14 17:34:14 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/927_912.mp4
# Thu Mar 14 17:34:15 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/928_160.mp4
# Thu Mar 14 17:34:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/929_962.mp4
# Thu Mar 14 17:34:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/930_763.mp4
# Thu Mar 14 17:34:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/931_936.mp4
# Thu Mar 14 17:34:16 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/932_384.mp4
# Thu Mar 14 17:34:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/933_925.mp4
# Thu Mar 14 17:34:18 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/934_918.mp4
# Thu Mar 14 17:34:19 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/935_733.mp4
# Thu Mar 14 17:34:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/936_931.mp4
# Thu Mar 14 17:34:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/937_888.mp4
# Thu Mar 14 17:34:21 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/938_987.mp4
# Thu Mar 14 17:34:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/939_115.mp4
# Thu Mar 14 17:34:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/940_941.mp4
# Thu Mar 14 17:34:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/941_940.mp4
# Thu Mar 14 17:34:22 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/942_943.mp4
# Thu Mar 14 17:34:23 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/943_942.mp4
# Thu Mar 14 17:34:24 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/944_032.mp4
# Thu Mar 14 17:34:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/945_044.mp4
# Thu Mar 14 17:34:25 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/946_049.mp4
# Thu Mar 14 17:34:26 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/947_951.mp4
# Thu Mar 14 17:34:27 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/948_965.mp4
# Thu Mar 14 17:34:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/949_868.mp4
# Thu Mar 14 17:34:28 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/950_836.mp4
# Thu Mar 14 17:34:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/951_947.mp4
# Thu Mar 14 17:34:30 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/952_882.mp4
# Thu Mar 14 17:34:31 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/953_974.mp4
# Thu Mar 14 17:34:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/954_976.mp4
# Thu Mar 14 17:34:32 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/955_078.mp4
# Thu Mar 14 17:34:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/956_958.mp4
# Thu Mar 14 17:34:33 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/957_959.mp4
# Thu Mar 14 17:34:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/958_956.mp4
# Thu Mar 14 17:34:35 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/959_957.mp4
# Thu Mar 14 17:34:36 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/960_999.mp4
# Thu Mar 14 17:34:37 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/961_069.mp4
# Thu Mar 14 17:34:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/962_929.mp4
# Thu Mar 14 17:34:38 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/963_879.mp4
# Thu Mar 14 17:34:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/964_174.mp4
# Thu Mar 14 17:34:39 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/965_948.mp4
# Thu Mar 14 17:34:40 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/966_988.mp4
# Thu Mar 14 17:34:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/967_984.mp4
# Thu Mar 14 17:34:41 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/968_884.mp4
# Thu Mar 14 17:34:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/969_897.mp4
# Thu Mar 14 17:34:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/970_973.mp4
# Thu Mar 14 17:34:42 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/971_564.mp4
# Thu Mar 14 17:34:43 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/972_718.mp4
# Thu Mar 14 17:34:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/973_970.mp4
# Thu Mar 14 17:34:44 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/974_953.mp4
# Thu Mar 14 17:34:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/975_978.mp4
# Thu Mar 14 17:34:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/976_954.mp4
# Thu Mar 14 17:34:45 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/977_075.mp4
# Thu Mar 14 17:34:47 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/978_975.mp4
# Thu Mar 14 17:34:48 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/979_875.mp4
# Thu Mar 14 17:34:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/980_992.mp4
# Thu Mar 14 17:34:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/981_985.mp4
# Thu Mar 14 17:34:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/982_004.mp4
# Thu Mar 14 17:34:49 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/983_113.mp4
# Thu Mar 14 17:34:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/984_967.mp4
# Thu Mar 14 17:34:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/985_981.mp4
# Thu Mar 14 17:34:50 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/986_994.mp4
# Thu Mar 14 17:34:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/987_938.mp4
# Thu Mar 14 17:34:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/988_966.mp4
# Thu Mar 14 17:34:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/989_993.mp4
# Thu Mar 14 17:34:51 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/990_008.mp4
# Thu Mar 14 17:34:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/991_064.mp4
# Thu Mar 14 17:34:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/992_980.mp4
# Thu Mar 14 17:34:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/993_989.mp4
# Thu Mar 14 17:34:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/994_986.mp4
# Thu Mar 14 17:34:52 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/995_233.mp4
# Thu Mar 14 17:34:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/996_056.mp4
# Thu Mar 14 17:34:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/997_040.mp4
# Thu Mar 14 17:34:53 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/998_561.mp4
# Thu Mar 14 17:34:54 2024 : /home/kyr/GazeForensicsData/cropped_videos/FF++_crop_basic/c40/fake/NeuralTextures/999_960.mp4
